# %% [markdown]
# ## Testing The Chatbot Filtering

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

DATABASE_FILE = "../hotel_recommendation/trvago_extended_new_neighs.csv"
db = pd.read_csv(DATABASE_FILE, sep="\t").ix[:,1:]

# %%
db.to_csv(DATABASE_FILE, sep="\t")

# %%
dfile2 = "../trivago_data/pandas_dbs/dataset_visualization.csv"
db2 = pd.read_csv(dfile2, sep="\t").ix[:,1:]

db2.head()
# Out:
#         city            hotel_name                             email  \
# 0  Barcelona        Hotel HCC Open                 open@hcchotels.es
# 1  Barcelona         Hcc Montblanc            montblanc@hcchotels.es
# 2  Barcelona   Ayre Hotel Gran Via           granvia@ayrehoteles.com
# 3  Barcelona  NH Barcelona Stadium  nhbarcelonastadium@nh-hotels.com
# 4  Barcelona    Duquesa de Cardona        info@hduquesadecardona.com
#
#              phone postal_code  price  star_count  \
# 0   +34(93)2893500       08015   89.0           3
# 1   +34(93)3435555       08003  116.0           3
# 2  +34(93)3675500        08004   98.0           4
# 3   +34(93)3399050       08028  137.0           4
# 4   +34(93)2689090       08002  208.0           4
#
#                                     street        type  \
# 0                           Diputacio, 100  [u'Hotel']
# 1                         Via Laietana, 61  [u'Hotel']
# 2  Gran Via de les Corts Catalanes 322-324  [u'Hotel']
# ...

# %%
assert db.neighbourhood.unique().all() == db2.neighbourhood.unique().all()

# %%
db[db.neighbourhood == "la Sagrada Familia"]
# Out:
#                                             hotel_name  city  price  \
# 118                            Gaudi's Nest Apartments     2    175
# 170                                    Sagrada Familia     2    101
# 233                                Ayre Hotel Rosellon     2    112
# 258                              Bbarcelona Apartments     2    214
# 294                 Happy People Sagrada Familia Gaud?     2    151
# 339                     Bcn Sagrada Familia Apartments     2    109
# 344        Bbarcelona Sagrada Familia Garden Apartment     2    194
# 349                               Hispanos Siete Suiza     2    199
# 393                                   Hostal Hostemplo     2    138
# 400                 Centric Sagrada Familia Apartments     2    114
# 407                        Eric Vökel Industria Suites     2    116
# 431                  Trivao Sagrada Familia Apartments     2    165
# 435  Bbarcelona Apartments Sagrada Familia Executiv...     2    194
# ...

# %%
np.asarray(db.price)
# Out:
# array([113,  90, 109, 329,  70, 119,  44,  57, 125,  49, 103, 220, 198,
#        108,  62,  45,  65,  72, 112,  63, 105, 115, 116, 218, 153,  66,
#         72,  54, 105,  94,  90,  45,  89,  98, 100,  94,  48,  59, 100,
#        110,  50,  49,  55, 101, 175, 118, 119,  56, 108, 122,  67, 104,
#         99,  65, 101,  50, 146,  58,  90,  85,  99,  89,  97,  59, 137,
#        112, 117,  73,  85,  86, 107, 166,  95,  58,  90,  39, 114,  48,
#         92,  81, 267,  99,  42,  50,  58,  36,  37, 140,  50, 122,  59,
#        130,  93,  80,  86,  31, 105,  95, 105, 125, 146, 166,  50,  44,
#         89,  51, 108, 126, 189,  69,  70, 129, 149,  87,  93,  46, 135,
#        111, 175, 148,  76,  98, 145,  69,  95,  96, 100, 110,  94,  46,
#         97, 135, 119,  60, 152, 119, 150,  34, 136,  35,  85, 331, 150,
#        175,  94, 110, 105,  80, 151,  65, 107, 112, 135,  78,  77,  88,
#         27, 113, 100,  59, 175,  99,  96,  72,  40, 105, 102,  87,  98,
# ...

# %%
db.to_csv(DATABASE_FILE, sep="\t")

# %% [markdown]
# ### Getting the neighbourhoods for Barcelona

# %%
from shapely.geometry import shape, Point
import json
from unidecode import unidecode

f_geojson = "neighbourhoods.geojson"

# get json file as js
with open(f_geojson,'r') as f:
    js = json.load(f)

# %%
neighbourhoods = {}

for row in db.iterrows():
    neighbourhoods[row[0]] = "" # key: index
    lat = float(row[1]['lat'])
    lon = float(row[1]['lon'])
    p = Point(lon,lat)
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(p):
            neighbourhoods[row[0]] = (unidecode(feature['properties']['neighbourhood']))
            break

# %%
neighs = pd.DataFrame(index = neighbourhoods.keys(), columns=["neighbourhood"], data = neighbourhoods.values())
db["neighbourhood"] = neighs.neighbourhood

# %%
db.neighbourhood.ix[7]
# Out:
# ''

# %%
db.loc[db.neighbourhood == '','neighbourhood'] = "outskirt"

# %%
from collections import Counter

nb_counts = Counter(db.neighbourhood)
tdf = pd.DataFrame.from_dict(nb_counts, orient='index').sort_values(by=0)
tdf.plot(kind='bar', figsize=(11,8))

# %%
import distance
import numpy as np

def nearest_barri(barri_user, barris):
    w, h = len(barris), len(barri_user.split())
    min_dist_matrix = [[0 for x in range(w)] for y in range(h)] 
    
    # Measure distances of all combinations
    for word,k in zip(barri_user.split(), range(len(barri_user.split()))):
        for barri,i in zip(barris,range(len(barris))):
            words_barri = barri.split()
            dist = [None]*len(words_barri)
            for word_barri,j in zip(words_barri,range(len(words_barri))):
                dist[j] = distance.levenshtein(barri_user,word_barri)
            min_dist_matrix[k][i] = min(dist)
    lev_dist = np.sum(min_dist_matrix, axis = 0)
    idxs = lev_dist.argsort()[:3] # return three most similar neighbourhoods
#     print np.argmin(lev_dist)
#     match = barris[np.argmin(lev_dist)]
    return list(np.asarray(barris)[idxs])


def nearest_neighbor(input, neighbourhoods):
    w, h = len(barris), len(input.split())
    min_dist_matrix = [[0 for x in range(w)] for y in range(h)] 
    
    # Measure distances of all combinations
    for word,k in zip(input.split(), range(len(input.split()))):
        for neigh, i in zip(neighbourhoods, range(len(neighbourhoods))):
            words_neigh = neigh.split()
            dist = [None]*len(words_neigh)
            for word_neigh,j in zip(words_neigh,range(len(words_neigh))):
                dist[j] = distance.levenshtein(input, word_neigh)
            min_dist_matrix[k][i] = min(dist)
    lev_dist = np.sum(min_dist_matrix, axis = 0)
    idxs = lev_dist.argsort()[:3] # return three most similar neighbourhoods
#     print np.argmin(lev_dist)
#     match = barris[np.argmin(lev_dist)]
    return list(np.asarray(neighbourhoods)[idxs])

# %%
barris = list(set(db.neighbourhood))

# %%
user = ""

nearest_neighbor(user, barris)
# Out:
# ['la Maternitat i Sant Ramon']

# %%
len(list(db.neighbourhood.unique()))
# Out:
# 43

# %%
db2.head()
# Out:
#         city                  name                             email  \
# 1  Barcelona        Hotel HCC Open                 open@hcchotels.es
# 2  Barcelona         Hcc Montblanc            montblanc@hcchotels.es
# 3  Barcelona   Ayre Hotel Gran Via           granvia@ayrehoteles.com
# 4  Barcelona  NH Barcelona Stadium  nhbarcelonastadium@nh-hotels.com
# 5  Barcelona    Duquesa de Cardona        info@hduquesadecardona.com
#
#              phone postal_code price star_count  \
# 1   +34(93)2893500       08015    89          3
# 2   +34(93)3435555       08003   116          3
# 3  +34(93)3675500        08004    98          4
# 4   +34(93)3399050       08028   137          4
# 5   +34(93)2689090       08002   208          4
#
#                                     street     type  \
# 1                           Diputacio, 100  [Hotel]
# 2                         Via Laietana, 61  [Hotel]
# 3  Gran Via de les Corts Catalanes 322-324  [Hotel]
# ...

# %%
web = db2.web[1]

# %%
from urlparse import urlparse

urlparse(web).netloc
# Out:
# 'www.hcchotels.com'

# %%
db["price"] = db["price"].apply(pd.to_numeric).astype(np.float64)

# %%
db["price"]
# Out:
# 0      113.0
# 1       90.0
# 2      109.0
# 3      329.0
# 4       70.0
# 5      119.0
# 6       44.0
# 7       57.0
# 8      125.0
# 9       49.0
# 10     103.0
# 11     220.0
# 12     198.0
# 13     108.0
# 14      62.0
# 15      45.0
# 16      65.0
# 17      72.0
# 18     112.0
# 19      63.0
# 20     105.0
# 21     115.0
# 22     116.0
# 23     218.0
# 24     153.0
# 25      66.0
# 26      72.0
# 27      54.0
# 28     105.0
# 29      94.0
#        ...
# 538    221.0
# 539    194.0
# 540     40.0
# 541    111.0
# 542    119.0
# 543     45.0
# 544     82.0
# 545    173.0
# 546     98.0
# 547    110.0
# 548    123.0
# 549    142.0
# 550    129.0
# 551     94.0
# 552    348.0
# 553     85.0
# 554     96.0
# 555    159.0
# 556    191.0
# 557     98.0
# 558    133.0
# 559    275.0
# 560    126.0
# 561    110.0
# 562    103.0
# 563    121.0
# 564     99.0
# 565    125.0
# 566    104.0
# 567     79.0
# Name: price, dtype: float64

# %%
min_price = db["price"].min()
max_price = db["price"].max()

print min_price
print max_price

db[(db['price'] >= max(75.0, min_price)) & (db['price'] <= min(100.0,max_price))].head()
# Out:
# 27.0
# 633.0
#                       hotel_name  city  price  quality_test  total_rat  \
# 1                 Hotel HCC Open     2   90.0             0          0
# 29                 Eurostars Lex     2   94.0             0          0
# 30  Salles Hotel Ciutat del Prat     2   90.0             0          0
# 32          Expo Hotel Barcelona     2   89.0             1          0
# 33           Hesperia Presidente     2   98.0             0          0
#
#     premium        lat       lon  part_total_rat  breakfast  \
# 1         0  41.381699  2.155100            1305         73
# 29        0  41.365517  2.130544            1544         76
# 30        0  41.325001  2.087401            3230         78
# 32        0  41.379173  2.142888            6620         77
# 33        0  41.394199  2.149200            1735         83
#
#                 ...                pool_free  restaurant_free  spa_free  \
# 1               ...                      0.0              0.0       0.0
# ...

# %%
db2.web
# Out:
# 0                 http://www.hcchotels.com/eng/open.html
# 1       http://www.hcchotels.es/en/hotel/3/hcc-montblanc
# 2      http://www.ayrehoteles.com/hotel-gran-via/?utm...
# 3      http://www.nh-hotels.com/hotel/nh-barcelona-st...
# 4                       http://www.hduquesadecardona.com
# 5      http://www.chicandbasic.com/hotel-barcelona-bo...
# 6                      http://www.exeramblasboqueria.com
# 7      http://www.nh-hotels.com/hotel/hesperia-presid...
# 8      http://www.ayrehoteles.com/en/hotel-rosellon/?...
# 9      http://www.hoteles-catalonia.com/es/nuestros_h...
# 10     http://www.hotelsansidiputacio.com/?wadsrc=dl_...
# 11                       http://www.hotelvillaemilia.com
# 12     http://www.ayrehoteles.com/hotel-caspe/?utm_so...
# 13     http://www.h10hotels.com/en/hotel/barcelona-ho...
# 14     http://www.nh-hotels.com/hotel/nh-sants-barcelona
# 15     http://www.axelhotels.com/en/two-hotel-barcelo...
# ...

# %%
print("Fitting the recommender to user...")
features = {'price': (40.0, 100.0), 'centrality': None, 'cityName': u'Barcelona', 'neighbourhood': "la Dreta de l'Eixample", 'cityInt': 2}
print(features)
city            = features["cityInt"]
neighbourhood   = features["neighbourhood"]
# room            = self.features["room"]
centrality      = features["centrality"]
price           = features["price"]
feats           = [] # ["value_for_money", "location"]

df = db.copy()
print(df.shape)
# CITY
df = df[df['city'] == city]

# EXTRA FEATURES
if feats:
    df = filter_by_features(df, feats)

# NEIGHBOURHOOD
if neighbourhood:
    df = df[df["neighbourhood"] == neighbourhood]
# CENTRALITY
else:
    if centrality == "Much":
        df = df[df['is_hotel_very_centric'] == True]
    elif centrality == "Not much":
        df = df.loc[df['is_hotel_centric'] == True]
    elif centrality == "Completely not":
        df = df.loc[(df['is_hotel_very_centric'] == False) & df['is_hotel_centric'] == False]
    else:
        df = df.loc[df['is_neighbourhood_very_centric'] == True]

# ROOM TYPE
# if room == "Individual":
#     df = df[df["individual_bed"] == 1]
# elif room == "Double":
#     df = df.loc[(df.ix[:,[19,20,21,24]] == 1).any(axis=1)] # at least one true value from [double_bed, king_bed, queen_bed, two_ind_beds]
# elif room == "More":
#     df = df.loc[(df.ix[:,[23,25,26,27]] == 1).any(axis=1)] # same for [four_bed, two_ind_beds, five_bed, six_bed, triple]

# PRICE
if price is not None:
    print(df.shape)
    min_price = df["price"].min()
    max_price = df["price"].max()

    df = df[(df['price'] >= max(price[0], min_price)) & (df['price'] <= min(price[1], max_price))]

# sort hotels by rating values?
df = df.ix[df.ix[:,9:18].mean(axis=1).sort_values(ascending=False).index]

preds = df.hotel_name
success = len(preds) != 0
print("Done. Succes:", success)

df
# Out:
# Fitting the recommender to user...
# {'price': (40.0, 100.0), 'cityInt': 2, 'cityName': u'Barcelona', 'neighbourhood': "la Dreta de l'Eixample", 'centrality': None}
# (568, 88)
# (110, 88)
# ('Done. Succes:', True)
#                        hotel_name  city  price  quality_test  total_rat  \
# 257                     Constanza     2  100.0             0          0
# 284                        Actual     2   89.0             0          0
# 276                Praktik Rambla     2   89.0             0          0
# 335               H10 Universitat     2   77.0             1          0
# 113          Hotel Praktik Garden     2   87.0             0          0
# 249                     Hcc Taber     2   79.0             0          0
# 187                  SERHS Carlit     2   80.0             0          0
# 551             Mihlton Barcelona     2   94.0             0          0
# 200          Casa Con Estilo Bruc     2  100.0             0          0
# ...

# %%
db2.name.astype(str).all() == db.hotel_name.astype(str).all()
# Out:
# False

# %%
db2.to_csv(dfile2, sep="\t")

# %%
# Out:
# 0                                           Sant Cugat
# 1                                       Hotel HCC Open
# 2                                      Sansi Diputacio
# 3                                 Hotel Arts Barcelona
# 4                                   Medium Sitges Park
# 5                          Two Hotel Barcelona By Axel
# 6                                  Campanile Barcelona
# 7                                   Campanile Cornellà
# 8                                  Ayre Hotel Gran Vía
# 9                               Eurostars Barberà Parc
# 10                                        Dolce Sitges
# 11                                  Duquesa de Cardona
# 12                                         Vincci Gala
# 13                             Front Maritim Barcelona
# 14                                  Sidorme Viladecans
# 15                                         Hotel Subur
# 16                                      La Santa María
# ...

# %%
db2[db2.hotel_name == "Hotel Arts Barcelona"]
# Out:
#          city            hotel_name                                 email  \
# 22  Barcelona  Hotel Arts Barcelona  rc.bcnrz.call.center@ritzcarlton.com
#
#              phone postal_code  price  star_count                     street  \
# 22  +34(93)2211000       08005  329.0           5  Carrer de la Marina 19-21
#
#           type                                web        lat     lon  \
# 22  [u'Hotel']  http://www.hotelartsbarcelona.com  41.387001  2.1964
#
#      neighbourhood
# 22  la Barceloneta

# %%
db2.head()
# Out:
#         city            hotel_name                             email  \
# 0  Barcelona        Hotel HCC Open                 open@hcchotels.es
# 1  Barcelona         Hcc Montblanc            montblanc@hcchotels.es
# 2  Barcelona   Ayre Hotel Gran Via           granvia@ayrehoteles.com
# 3  Barcelona  NH Barcelona Stadium  nhbarcelonastadium@nh-hotels.com
# 4  Barcelona    Duquesa de Cardona        info@hduquesadecardona.com
#
#              phone postal_code  price  star_count  \
# 0   +34(93)2893500       08015   89.0           3
# 1   +34(93)3435555       08003  116.0           3
# 2  +34(93)3675500        08004   98.0           4
# 3   +34(93)3399050       08028  137.0           4
# 4   +34(93)2689090       08002  208.0           4
#
#                                     street        type  \
# 0                           Diputacio, 100  [u'Hotel']
# 1                         Via Laietana, 61  [u'Hotel']
# 2  Gran Via de les Corts Catalanes 322-324  [u'Hotel']
# ...

# %%
df = pd.merge(db, db2, on="hotel_name").drop([u'price_y', u'lat_y',u'lon_y', u'neighbourhood_y'], axis=1)

# %%
b = [u'hotel_name', u'city_int', u'price', u'quality_test', u'total_rat',
       u'premium', u'lat', u'lon', u'part_total_rat', u'breakfast',
       u'cleanliness', u'comfort', u'facilities', u'food', u'hotel_condition',
       u'location', u'room', u'service', u'value_for_money', u'double_bed',
       u'king_bed', u'queen_bed', u'individual_bed', u'four_bed',
       u'two_ind_beds', u'five_bed', u'six_bed', u'triple', u'water_sports',
       u'winter_sports', u'family', u'party', u'fitness', u'gay_friendly',
       u'gourmets', u'big_groups', u'honey_moon', u'business', u'adults_only',
       u'single_status', u'pet_travelers', u'atrapalo_rc',
       u'customer_alliance_rc', u'expedia_rc', u'holiday_check_rc',
       u'hoteles_rc', u'hotelsclick_rc', u'splendia_rc', u'superbreak_rc',
       u'vinivi_rc', u'zoover_rc', u'hostelbookers_rc', u'atrapalo_r',
       u'customer_alliance_r', u'expedia_r', u'holiday_check_r', u'hoteles_r',
       u'hotelsclick_r', u'splendia_r', u'superbreak_r', u'vinivi_r',
       u'zoover_r', u'hostelbookers_r', u'air_conditioner', u'bar_in_hotel',
       u'gym', u'pet_allowed', u'parking', u'pool', u'restaurant', u'spa',
       u'wifi_room', u'wifi_hall', u'air_conditioner_free',
       u'bar_in_hotel_free', u'gym_free', u'pet_allowed_free', u'parking_free',
       u'pool_free', u'restaurant_free', u'spa_free', u'wifi_room_free',
       u'wifi_hall_free', u'hotel_type', u'neighbourhood',
       u'is_hotel_very_centric', u'is_hotel_centric',
       u'is_neighbourhood_very_centric', u'email', u'phone', u'postal_code',
       u'star_count', u'street', u'type', u'web']

df.columns = [u'hotel_name', u'city_int', u'price', u'quality_test', u'total_rat',
       u'premium', u'lat', u'lon', u'part_total_rat', u'breakfast',
       u'cleanliness', u'comfort', u'facilities', u'food', u'hotel_condition',
       u'location', u'room', u'service', u'value_for_money', u'double_bed',
       u'king_bed', u'queen_bed', u'individual_bed', u'four_bed',
       u'two_ind_beds', u'five_bed', u'six_bed', u'triple', u'water_sports',
       u'winter_sports', u'family', u'party', u'fitness', u'gay_friendly',
       u'gourmets', u'big_groups', u'honey_moon', u'business', u'adults_only',
       u'single_status', u'pet_travelers', u'atrapalo_rc',
       u'customer_alliance_rc', u'expedia_rc', u'holiday_check_rc',
       u'hoteles_rc', u'hotelsclick_rc', u'splendia_rc', u'superbreak_rc',
       u'vinivi_rc', u'zoover_rc', u'hostelbookers_rc', u'atrapalo_r',
       u'customer_alliance_r', u'expedia_r', u'holiday_check_r', u'hoteles_r',
       u'hotelsclick_r', u'splendia_r', u'superbreak_r', u'vinivi_r',
       u'zoover_r', u'hostelbookers_r', u'air_conditioner', u'bar_in_hotel',
       u'gym', u'pet_allowed', u'parking', u'pool', u'restaurant', u'spa',
       u'wifi_room', u'wifi_hall', u'air_conditioner_free',
       u'bar_in_hotel_free', u'gym_free', u'pet_allowed_free', u'parking_free',
       u'pool_free', u'restaurant_free', u'spa_free', u'wifi_room_free',
       u'wifi_hall_free', u'hotel_type', u'neighbourhood',
       u'is_hotel_very_centric', u'is_hotel_centric',
       u'is_neighbourhood_very_centric', u'city_name', u'email', u'phone',
       u'postal_code', u'star_count', u'street', u'type', u'web']

# %%
df.to_csv("../trivago_data/trivago.csv", sep="\t")

# %%
pd.read_csv("../trivago_data/trivago.csv", sep="\t").ix[:,1:]
# Out:
#                                           hotel_name  city_int  price  \
# 0                                         Sant Cugat         2  113.0
# 1                                     Hotel HCC Open         2   90.0
# 2                                    Sansi Diputacio         2  109.0
# 3                               Hotel Arts Barcelona         2  329.0
# 4                                 Medium Sitges Park         2   70.0
# 5                        Two Hotel Barcelona By Axel         2  119.0
# 6                                Campanile Barcelona         2   44.0
# 7                                       Dolce Sitges         2  103.0
# 8                                 Duquesa de Cardona         2  220.0
# 9                                        Vincci Gala         2  198.0
# 10                           Front Maritim Barcelona         2  108.0
# 11                                Sidorme Viladecans         2   62.0
# ...

# %%
import cPickle

with open("../../predict_flights/Rfregressor_airport.pickle", "rb") as input_file:
    Rfregressor = cPickle.load(input_file)

# %%
def find_nearest(input, list_from, threshold = 0.005):
    w, h = len(list_from), len(input.split())
    min_dist_matrix = [[0 for x in range(w)] for y in range(h)]

    # Measure distances of all combinations
    for word,k in zip(input.split(), range(len(input.split()))):
        for element, i in zip(list_from, range(len(list_from))):
            words_element = element.split()
            dist = [None]*len(words_element)
            for word_element,j in zip(words_element, range(len(words_element))):
                dist[j] = distance.levenshtein(input, word_element)
            min_dist_matrix[k][i] = min(dist)
    lev_dist = np.sum(min_dist_matrix, axis = 0)
    idxs = lev_dist.argsort()[:3] # return three most similar elements from list_from
    lev_dist_norm = lev_dist / float(sum(lev_dist))

    if abs(lev_dist_norm[idxs[0]] - lev_dist_norm[idxs[1]]) > threshold:
        return list_from[idxs[0]]
    elif abs(lev_dist_norm[idxs[1]] - lev_dist_norm[idxs[2]]) > threshold:
        return list_from[idxs[0:1]]
    else:
        return list(np.asarray(list_from)[idxs])

# %%
user = "la sagrada"
neighs = list(set(df.neighbourhood))

find_nearest(user, neighs)
# Out:
# 'la Sagrada Familia'

# %%
int(2L)
# Out:
# 2

# %%
df[df.neighbourhood == 'la Sagrada Familia'].count()["hotel_name"]
# Out:
# 14

# %%
#coding utf-8

import numpy as np
from datetime import datetime as dtime
import pandas as pd
import datetime
import cPickle
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder

class FlightPredictor():

    def __init__(self, regressor_file, oilcsv_file):

        self.oil_prices     = self.init_oil(oilcsv_file)
#         self.rfregressor    = self.init_regressor(regressor_file)
        self.airport, self.airport_cities, self.airport_dict = self.init_airport()
        self.airport_array  = np.array(self.airport)
        self.encoder        = self.init_encoder()

    def init_oil(self, oilcsv):
        Oil_prices = pd.read_csv(oilcsv)
        Oil_prices.DCOILBRENTEU[Oil_prices.DCOILBRENTEU == '.'] = float('nan')
        Dates = [(dtime.today().date() - datetime.timedelta(days=x)).isoformat() for x in range(0, 365)]
        Dates = pd.DataFrame({'DATE': Dates})
        Oil_prices = Oil_prices.merge(Dates,how = 'right').sort_values('DATE').fillna(method = 'ffill')
        return Oil_prices

    def init_regressor(self, rfile):
        with open(rfile, "rb") as f:
            reg = cPickle.load(f)
        return reg

    def init_airport(self):
        airport = ['LCY', 'LHR', 'LGW', 'LTN', 'SEN', 'STN',
                   'CDG', 'ORY', 'BVA',
                   'MAD',
                   'ATH',
                   'FCO','CIA',
                   'BRU', 'CRL',
                   'BER', 'SXF',
                   'DME', 'SVO',
                   'SFO',
                   'JFK',
                   'PEK',
                   'EZE',
                   'GIG',
                   'DEL']
        airport_cities = ['london','london','london','london','london','london','paris','paris','paris','madrid','athens','rome','rome',
                         'brussels','brussels','berlin','berlin','moscow','moscow','san francisco','new york','beijing','buenos aires',
                         'rio de janeiro','new delhi']
        airport_dict = {"London": airport[0:6],
                        "Paris": airport[6:9],
                        "Madrid": [airport[9]],
                        "Athens": [airport[10]],
                        "Rome": airport[11:13],
                        "Brussels": airport[13:15],
                        "Berlin": airport[15:17],
                        "Moscow": airport[17:19],
                        "San Francisco": [airport[19]],
                        "New York": [airport[20]],
                        "Beijing": [airport[21]],
                        "Buenos Aires": [airport[22]],
                        "Rio de Janeiro": [airport[23]],
                        "New Delhi": [airport[24]]}
        return airport, airport_cities, airport_dict

    def get_airport_cities(self):
        return self.airport_dict.keys()
    
    def init_encoder(self):
        to_encode = []
        for i in range(25):
            for j in range(7):
                for k in range(7):
                    for l in range(12):
                        to_encode.append([i,j,k,l+1])
        enc = OneHotEncoder()
        enc.fit(to_encode)
        return enc

    def predict_lowest_price(self, departure_date, destination):
        Rfregressor_air = self.rfregressor[destination]
        today = dtime.today().date()
        departure_date = dtime.strptime(departure_date, '%Y-%m-%d').date()
        predict2 = []
        predict = []
        date = today
        for i in range((departure_date-today).days):
            date = today + datetime.timedelta(days=i)
            predict2.append([self.airport.index(destination),
                      date.weekday(),
                      departure_date.weekday(),
                      departure_date.month])
            predict.append([(departure_date-date).days,
                          float(self.oil_prices[self.oil_prices.DATE == today.isoformat()].DCOILBRENTEU.values[0])])
        predict3 = np.c_[predict, self.encoder.transform(predict2).toarray().tolist()]
        prediction = Rfregressor_air.predict(predict3)
        #return prediction
        days_wait_to_buy = [k1  for k1, k2 in enumerate(prediction) if k2 == min(prediction) ][0]
        price = min(prediction)
        return (today + datetime.timedelta(days=days_wait_to_buy) ).isoformat(), price, destination

    def find_best_flight(self, departure_date, destination):
        if destination in self.airport:
            day, price, airport = self.predict_lowest_price(departure_date, destination)
            return day, price, airport
        else:
            dest = destination.lower()
            airs = self.airport_array[[k for k,city in enumerate(self.airport_cities) if city == dest]]
            minprice = 1e10
            for air in airs:
                day, price, airport = self.predict_lowest_price(departure_date, air)
                if price < minprice:
                    minprice = price
                    minday = day
                    minairport = airport
            return day, price, airport

    # usage: flight_regressor.find_best_flight('2017-08-04','LCY')
    # usage: flight_regressor.find_best_flight('2017-08-04','London')

# %%
F = FlightPredictor("../../predict_flights/Rfregressor_airport.pickle", "../../predict_flights/DCOILBRENTEU.csv")
# Out:
# 25
# 25
# {'Athens': ['ATH'],
#  'Beijing': ['PEK'],
#  'Berlin': ['BER', 'SXF'],
#  'Brussels': ['BRU', 'CRL'],
#  'Buenos Aires': ['EZE'],
#  'London': ['LCY', 'LHR', 'LGW', 'LTN', 'SEN', 'STN'],
#  'Madrid': ['MAD'],
#  'Moscow': ['DME', 'SVO'],
#  'New Delhi': ['DEL'],
#  'New York': ['JFK'],
#  'Paris': ['CDG', 'ORY', 'BVA'],
#  'Rio de Janeiro': ['GIG'],
#  'Rome': ['FCO', 'CIA'],
#  'San Francisco': ['SFO']}

# %%
airport = ['LCY', 'LHR', 'LGW', 'LTN', 'SEN', 'STN',
                   'CDG', 'ORY', 'BVA',
                   'MAD',
                   'ATH',
                   'FCO','CIA',
                   'BRU', 'CRL',
                   'BER', 'SXF',
                   'DME', 'SVO',
                   'SFO',
                   'JFK',
                   'PEK',
                   'EZE',
                   'GIG',
                   'DEL']

# %%
F.find_best_flight('2017-08-04','LCY')
# Out:
# ('2017-07-13', 131.81630000000001, 'LCY')

# %%
F.find_best_flight('2017-08-04','London')
# Out:
# ('2017-07-08', 65.364999999999881, 'STN')

# %%
airport_cities = ['london','london','london','london','london','london','paris','paris','paris','madrid','athens','rome','rome',
                         'brussels','brussels','berlin','berlin','moscow','moscow','san francisco','new york','beijing','buenos aires',
                         'rio de janeiro','new delhi']
set(airport_cities)
# Out:
# {'athens',
#  'beijing',
#  'berlin',
#  'brussels',
#  'buenos aires',
#  'london',
#  'madrid',
#  'moscow',
#  'new delhi',
#  'new york',
#  'paris',
#  'rio de janeiro',
#  'rome',
#  'san francisco'}
