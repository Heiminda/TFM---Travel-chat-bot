# %%
import requests
import json
import numpy as np
from lxml import html

from bs4 import BeautifulSoup

# %% [markdown]
# ## Ratings

# %%
url = "https://www.trivago.es/api/v1/_cache/accommodation/6795/web34591/ratings.json?"
params = dict(requestId="v11_03_1_ae_es_ES_ES")

# %%
data = requests.get(url=url, params=params)

# %%
data_json = json.loads(data.text)

# %%
data_json
# Out:
# {u'hydraReviews': [{u'author': None,
#    u'date': {u'formatted': u'Noviembre 2016', u'month': u'11', u'year': 2016},
#    u'isTextTruncated': False,
#    u'partner': {u'id': 452,
#     u'name': u'Hoteles.com',
#     u'urls': {u'logo': {u'title': u'Opini\xf3n aut\xe9ntica de',
#       u'url': u'//ie2.trivago.com/images/layoutimages/Rating/Partner/452_mx.png'},
# ...

# %%
data_json.keys()
# Out:
# [u'metaReviews', u'ratingSummary', u'id', u'hydraReviews']

# %%
data_json["ratingSummary"]["ratingAspects"][0].keys()
# Out:
# [u'ratingText', u'index', u'percentage', u'type']

# %%
data_json["ratingSummary"]
# Out:
# {u'hasAdvertiserRatings': True,
#  u'hasQualityTests': False,
#  u'hotelAwards': [],
#  u'isInEu': True,
#  u'partnerReviewCount': 3585,
#  u'ratingAspects': [{u'index': 5,
#    u'percentage': 87,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'facilities'},
#   {u'index': 3,
#    u'percentage': 75,
#    u'ratingText': u'\xa1Buena!',
#    u'type': u'breakfast'},
#   {u'index': 5,
#    u'percentage': 88,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'service'},
#   {u'index': 5,
#    u'percentage': 91,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'cleanliness'},
#   {u'index': 5,
#    u'percentage': 91,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'comfort'},
#   {u'index': 5,
#    u'percentage': 85,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'food_and_drinks'},
#   {u'index': 5,
#    u'percentage': 85,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'location'},
#   {u'index': 5,
#    u'percentage': 88,
# ...

# %%
hotelId = data_json["id"]
rats = []

for rating in data_json["ratingSummary"]["ratingAspects"]:
    print rating
# Out:
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 87, u'type': u'facilities'}
# {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 75, u'type': u'breakfast'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 88, u'type': u'service'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 91, u'type': u'cleanliness'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 91, u'type': u'comfort'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 85, u'type': u'food_and_drinks'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 85, u'type': u'location'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 88, u'type': u'hotel_condition'}
# {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 83, u'type': u'value_for_money'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 90, u'type': u'room'}

# %%
data_json["ratingSummary"]["reviewRating"]
# Out:
# {u'index': 5, u'percentage': 89}

# %% [markdown]
# ####  Attributes of interest
#
#
#     data_json["ratingSummary"]["partnerReviewCount"] # number of total reviews from partners
#     data_json["ratingSummary"]["reviewPartners"] # list, each pos dict with dict {"name", "id", "ratingPercentage"}
#     data_json["ratingSummary"]["reviewRating"] # final hotel rating
#     data_json["ratingSummary"]["hasQualityTests"] # extra info
#     data_json["ratingSummary"]["ratingAspects"] # important, ratings of each hotel aspects

# %% [markdown]
# ## Complete Info

# %%
url2 = "https://www.trivago.es/api/v1/_cache/accommodation/99027/complete-info.json"

params2 = dict(requestId="v11_03_1_ae_es_ES_ES")

r = requests.get(url = url2, params = params2)

# %%
data = json.loads(r.text)
data
# Out:
# {u'accommodation': {u'address': {u'country': u'Espa\xf1a',
#    u'locality': u'Sitges',
#    u'postalCode': u'08870',
#    u'street': u'Jesus, 16'},
#   u'centroid': {u'latitude': 41.237034, u'longitude': 1.81022},
#   u'contact': {u'email': u'sitgespark@mediumhoteles.com',
#    u'fax': u'+34(93)8940839',
#    u'phone': u'+34(93)8940250',
#    u'web': u'http://www.mediumhoteles.com/es/espana/sitges/centro/hotel-medium-sitges-park'},
#   u'hotelStarRating': {u'isSuperior': False, u'starCount': 3},
#   u'id': 99027,
#   u'isPremiumPartner': False,
#   u'name': u'Medium Sitges Park',
#   u'reviewRating': {u'index': 4, u'percentage': 81},
#   u'types': [u'Hotel']},
#  u'adequateFor': [u'Lunas de miel', u'Gay friendly', u'Deportes acu\xe1ticos'],
#  u'amenities': {u'groupedFeatures': [{u'features': [{u'title': u'Aparcamiento'},
#      {u'title': u'Ascensor'},
#      {u'title': u'Bar del hotel'},
#      {u'title': u'Bar en la piscina'},
#      {u'title': u'Conserje'},
# ...

# %%
data["accommodation"]["types"]
# Out:
# [u'Hotel']

# %% [markdown]
# #### Attributes of interest
#
#     data["accommodation"]["address"]["postalCode"]
#     data["accommodation"]["address"]["street"]
#     data["accommodation"]["centroid"]["latitude"]
#     data["accommodation"]["centroid"]["longitude"]
#     data["accommodation"]["contact"]["email"]
#     data["accommodation"]["contact"]["fax"]
#     data["accommodation"]["contact"]["phone"]
#     data["accommodation"]["contact"]["web"]
#     data["accommodation"]["hotelStarRating"]["starCount"]
#     data["accommodation"]["isPremiumPartner"]
#     data["accommodation"]["types"]
#     data["accommodation"]["name"]
#
#     data["roomTypes"][0]["availableBeds"] # list
#     data["adequateFor"] # list
#
#     data["amenities"]["topFeatures"] # list, each pos interesting: {"isAvailable","isFreeOfCharge","title"}

# %% [markdown]
# ## Prices

# %%
# TODO get price/night through xpath

# %% [markdown]
# ## Get ids of all hotels in City

# %%
url = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-03-26&aDateRange%5Bdep%5D=2017-03-27&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iLimit=25&iIncludeAll=1&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"
u2 = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-03-26&aDateRange%5Bdep%5D=2017-03-27&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iOffset=0&iLimit=25&iIncludeAll=1&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"

params = dict(iOffset=0) # indicates page of search, it goes from 0 to 25 (page 1). 25 to 50 (page 2), etc...

page = requests.get(u2)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

url = "https://www.trivago.es/?cpt=3196503&iRoomType=7&iPathId=31965&aDateRange%5Barr%5D=2017-04-02&aDateRange%5Bdep%5D=2017-04-03&iGeoDistanceItem=0&iViewType=0&bIsSeoPage=false&bIsSitemap=false&"  

driver = webdriver.Chrome() 
driver.get(url)
WebDriverWait(driver,5)
xpath = "//script"
daily = driver.find_element_by_xpath(xpath)

# %%
daily.text
# Out:
# u''

# %%
import Cookie
import time

def parse_trivago_cookies(r):
    cookies = Cookie.SimpleCookie()
    cookies.load(r.headers['Set-Cookie'])
    
    return cookies

def get_trivago_cookies():
    headers = {
        'cache-control': 'max-age=0',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
    }
    
    r = requests.get("https://www.trivago.es", headers=headers)
    return parse_trivago_cookies(r)


def do_trivago_request(url, cookies):
    headers = {
        'cache-control': 'max-age=0',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
        'cookie': ''.join([name + '=' + morsel.coded_value for name, morsel in cookies.items()])
    }

    return requests.get(url, headers=headers)

def poll_until_not_empty(url, cookies, xpath):
    r = do_trivago_request(url, cookies)
    cookies = parse_trivago_cookies(r)
    
    page = html.fromstring(r.text)
    element = page.xpath(xpath)[0]
    
    if element.getchildren():
        return element, r
    
    print '[EMPTY] Retrying in 1s'
    time.sleep(1)
    return poll_until_not_empty(url, cookies, xpath)

# %%
li = ol.getchildren()[0]
li.values()
# Out:
# ['hotel item-order__list-item js_co_item', '0', '31965', '6738']

# %%
cookies = get_trivago_cookies()
url = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-04-02&aDateRange%5Bdep%5D=2017-04-03&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iOffset=0&iLimit=25&iIncludeAll=0&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"
xpath = "/html/body/div/main/div//ol"

ol,r = poll_until_not_empty(url, cookies, xpath)
print ol.getchildren()
r.text
# Out:
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [<Element li at 0x7f969d7b2f70>, <Element li at 0x7f969d7b2db8>, <Element li at 0x7f969d7b29f0>, <Element li at 0x7f969d7ae4c8>, <Element li at 0x7f969d7ae838>, <Element li at 0x7f969d6ccb50>, <Element li at 0x7f969d6ccd60>]
# ...

# %% [markdown]
# ## Trying another strategy
#
# Through request-response

# %%
req = "https://www.trivago.es/?iPathId=31965&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-04-02&aDateRange%5Bdep%5D=2017-04-03&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iOffset=0&iLimit=25&iIncludeAll=1&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.170045&aGeoCode%5Blat%5D=41.38702&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=3196503&iFilterTab=0&"

r1 = requests.get(req)
print r1.text
data = json.loads(r1.text)
# Out:
# <!DOCTYPE html><html lang="es" prefix="og: http://ogp.me/ns#"><head><!--
#     Want to get paid to dissect our code?
#     We're hiring developers: http://company.trivago.com/jobs
# --><script type="text/javascript">
# ...

# %%
data

# %%
data.keys()
# Out:
# [u'alternativeItems',
#  u'items',
#  u'state',
#  u'version',
#  u'snapshot',
#  u'metadata',
#  u'sdk']

# %%
data[""]
# Out:
# {u'aCategoryRange': [0, 1, 2, 3, 4, 5],
#  u'aConcepts': [3196503],
#  u'aDateRange': {u'arr': u'2017-04-02', u'dep': u'2017-04-03'},
#  u'aDefaultDateRange': {u'arr': u'2017-03-12', u'dep': u'2017-03-13'},
#  u'aField': [],
#  u'aGeoCode': {u'lat': 41.38702, u'lng': 2.170045},
#  u'aHotelTestClassifier': [],
#  u'aItemList': None,
#  u'aMapItems': [],
#  u'aMapViewport': None,
#  u'aOrField': [],
#  u'aOverallLiking': [1, 2, 3, 4, 5],
#  u'aPartner': [],
#  u'aPathList': None,
#  u'aPriceRange': {u'from': 0, u'to': 0},
#  u'aRateAttributes': [],
#  u'aRecommendedBy': [],
#  u'aRegion': None,
#  u'aReviewPartners': [],
#  u'aRooms': None,
#  u'aSortingOrderBoosting': [],
#  u'bDispMoreFilter': False,
#  u'bHotelTestContext': False,
#  u'bIsCacheResponse': False,
#  u'bIsCity': True,
#  u'bIsDefaultSnapshot': False,
#  u'bIsHotelTestHotel': False,
#  u'bIsMysteryGuestOnly': False,
#  u'bIsSeoPage': False,
#  u'bIsSitemap': False,
#  u'bIsTotalPrice': None,
# ...

# %%
# the response we should get instead of empty
data = json.loads('{"metadata":{"priceRange":{"from":2860,"to":64800},"displayPriceRange":{"from":29,"to":648},"reviewPartner":[],"hotelTest":[],"tags":null,"pathHasRatedItems":true,"topDealsOnly":true,"resultCount":781,"totals":{"default":"\u003Cspan class=\u0022result_count\u0022\u003E781\u003C\/span\u003E de 5.712 hoteles","result_count_formatted":"781","total_count_formatted":"5.712"},"trackers":"","rateAttributes":{"breakfast":true},"pagination":{"offset":0,"perPage":25,"total":781,"max":500},"gtm":{"variables":{"checkInDate":"20170402","checkOutDate":"20170403","checkInISODate":"2017-04-02","checkOutISODate":"2017-04-03","cipTc":"","criteoTrackingId":"7712041","criteoUserSegment":"16","deDuplication":"0","locale":"ES","trackingId":"C2uVpRLa65f1t8y47109VI8ICy","requestId":"WME7zAoBAkEAAM4EpiUAAAAj","doubleClick":"\u003Cimg src=\u0022http:\/\/ad-emea.doubleclick.net\/activity;src=3203335;type=hp;cat=globa490;u2=4;u1=ES;u4=106;u3=0;u6=999;u5=9999;u8=1;u7=2010;u9=0;u10=2;u11=40120;u12=31965;u13=31965;ord=8t8ebknab1icjh4n6m5214spc5?\u0022 \/\u003E","countClickOut":"14","countClickOutSession":"0","currencyCode":"EUR","language":"es","cip":"0","cipGroup":"0","firstVisit":"","pageType":"region","criteoAccountId":"2255","agentId":"1","sessionId":"8t8ebknab1icjh4n6m5214spc5","facebookExternalId":"cc99c33083056c09e27510e9d8c5728dc6cf502fbe68b1d56edf709c246be39f","hashedUserEmail":"","firstPage":"","pathRegionName":"Catalu\u00f1a","daysToCheckIn":"24","pathName":"Barcelona","itemId":"","itemRate":"91","itemRateStay":"91","sortingOption":"relevance desc","roomType":"7","roomTypeName":"double","ratingCat":"","pathCountryName":"Espa\u00f1a","criteoItemList":"\u002740120\u0027,\u00276836\u0027,\u002740692\u0027","lengthOfStay":"1","itemIds":"40120,6836,40692,40704,6831,216376,6834,40650,3818752,110635,126926,40254,590576,16805,40504,2143896,83855,2256940,40562,1991881,14794,2532876,1270887,40635,159437","starCat":"0,1,2,3,4,5","guestCount":"2","pathId":"31965","itemRates":"91,109,114,88,171,125,130,116,149,329,82,98,114,99,120,115,106,91,116,97,150,188,134,185,119"},"events":["pollingDone"]},"fields":{"1_1":433,"1_129":1,"1_772":4,"1_132":2,"1_134":3,"1_776":2,"1_137":3,"1_267":1,"1_14":1,"1_783":1,"1_785":1,"1_1045":1,"1_150":1,"1_280":121,"1_1051":7,"1_797":1,"1_672":5,"1_161":2,"1_37":3,"1_168":1,"1_43":2,"1_301":2,"1_1070":3,"1_814":10,"1_175":5,"1_176":1,"1_311":1,"1_823":2,"1_56":25,"1_569":2,"1_698":1,"1_699":1,"1_571":3,"1_572":1,"1_316":1,"1_60":1,"1_317":2,"1_189":13,"1_190":1,"1_832":1,"1_707":1,"1_580":1,"1_964":1,"1_838":2,"1_204":1,"1_76":1,"1_717":1,"1_721":3,"1_338":3,"1_722":3,"1_723":7,"1_83":15,"1_596":3,"1_84":3,"1_725":3,"1_726":2,"1_599":1,"1_728":2,"1_346":2,"1_224":1,"1_97":1,"1_364":1,"1_112":1,"1_244":5,"1_121":13,"1_762":4,"1_127":2,"64":78,"71":142,"396":84,"13":174,"17":16,"19":188,"20":630,"23":140,"24":26,"25":424,"27":307,"28":104,"30":172,"31":313,"32":2,"34":49,"35":132,"36":23,"37":388,"40":20,"41":259,"44":545,"45":450,"47":251,"48":592,"245":27,"437":516,"246":9,"247":10,"55":1,"56":61,"249":267,"57":147,"58":79,"59":425,"60":50,"62":682,"63":304,"free_wifi":1031,"256":140,"257":198,"65":64,"97":458,"258":75,"101":144,"74":388,"75":585,"77":216,"80":625,"82":558,"402":14,"83":683,"85":228,"86":658,"438":515,"87":206,"92":371,"253":623,"93":486,"254":669,"255":174,"95":429,"484":42,"486":5,"502":571,"494":113,"128":78,"129":151,"130":150,"259":66,"260":64,"112":9,"113":101,"114":126,"115":43,"116":172,"117":78,"118":301,"119":11,"120":186,"122":16,"123":55,"124":167,"125":2,"126":52,"127":112,"148":49,"276":116,"262":85,"263":115,"266":132,"475":20,"331":5,"332":182,"159":300,"466":118,"99":53,"646":22,"160":416,"161":44,"162":10,"355":99,"164":66,"166":79,"167":67,"226":2,"419":7,"227":31,"420":6,"421":16,"230":686,"231":19,"232":85,"520":103,"234":30,"274":1,"219":1,"220":97,"221":1,"374":12,"347":124,"377":373,"378":196,"379":49,"467":2,"357":4,"394":2,"38":412,"39":87,"250":4,"51":83,"54":34,"424":6,"425":21,"10":17,"42":118,"426":22,"427":2,"61":59,"15":38,"432":158,"49":355,"433":13,"428":119,"429":123,"430":106,"431":63},"zoomLevel":11,"errors":{"pos1":null,"pos2":null,"pos3":null,"code":0},"pos2n":null,"poi":[]},"items":[{"distance":{"pathName":"Barcelona","regionName":"","poi":"Plaza Espa\u00f1a","isPoiInCenter":false,"value":"0,9","unit":"km"},"id":40120,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"1,9","unit":"km"},"id":6836,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":50,"comparePrice":"224 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Camp Nou","isPoiInCenter":false,"value":"0,4","unit":"km"},"id":40692,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":40,"comparePrice":"192 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Camp Nou","isPoiInCenter":false,"value":"1,4","unit":"km"},"id":40704,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"168 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Camp Nou","isPoiInCenter":false,"value":"1,1","unit":"km"},"id":6831,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Plaza Espa\u00f1a","isPoiInCenter":false,"value":"0,3","unit":"km"},"id":216376,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":55,"comparePrice":"286 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"1,7","unit":"km"},"id":6834,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"251 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"3,3","unit":"km"},"id":40650,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":40,"comparePrice":"198 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Plaza Espa\u00f1a","isPoiInCenter":false,"value":"0,7","unit":"km"},"id":3818752,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"0,9","unit":"km"},"id":110635,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"1,2","unit":"km"},"id":126926,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":40,"comparePrice":"141 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"0,9","unit":"km"},"id":40254,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"192 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Camp Nou","isPoiInCenter":false,"value":"1,5","unit":"km"},"id":590576,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"222 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Plaza Espa\u00f1a","isPoiInCenter":false,"value":"2,1","unit":"km"},"id":16805,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":50,"comparePrice":"214 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"1,8","unit":"km"},"id":40504,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"229 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"3,3","unit":"km"},"id":2143896,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":40,"comparePrice":"196 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Plaza Espa\u00f1a","isPoiInCenter":false,"value":"0,3","unit":"km"},"id":83855,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":40,"comparePrice":"179 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Plaza Espa\u00f1a","isPoiInCenter":false,"value":"0,5","unit":"km"},"id":2256940,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"175 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"3,2","unit":"km"},"id":40562,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"1,6","unit":"km"},"id":1991881,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"184 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Camp Nou","isPoiInCenter":false,"value":"1,2","unit":"km"},"id":14794,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"1,5","unit":"km"},"id":2532876,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":40,"comparePrice":"322 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Sagrada Familia","isPoiInCenter":false,"value":"0,2","unit":"km"},"id":1270887,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":45,"comparePrice":"264 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"1,3","unit":"km"},"id":40635,"isItemAvailable":true,"topDeal":{"isTopDeal":true,"criterionId":1,"criterion":"top_deal_save","percentage":50,"comparePrice":"406 \u20ac"}},{"distance":{"pathName":"Barcelona","regionName":"","poi":"Barceloneta","isPoiInCenter":false,"value":"1,7","unit":"km"},"id":159437,"isItemAvailable":true,"topDeal":{"isTopDeal":false,"criterionId":0,"criterion":"","percentage":0,"comparePrice":""}}],"alternativeItems":[],"state":1,"version":"v11_03_1_ai","sdk":"8t8ebknab1icjh4n6m5214spc5:1000827-R65590205472-20170309112557"} ' )  

for item in data["items"]:
    print item["id"] # WE WANT THIS!!!!!!
