# %%
import requests
import json
import numpy as np
from lxml import html

from bs4 import BeautifulSoup

# %% [markdown]
# ## Ratings

# %%
url = "https://www.trivago.es/api/v1/_cache/accommodation/6795/web34591/ratings.json?"
params = dict(requestId="v11_03_1_ae_es_ES_ES")

# %%
data = requests.get(url=url, params=params)

# %%
data_json = json.loads(data.text)

# %%
data_json
# Out:
# {u'hydraReviews': [{u'author': None,
#    u'date': {u'formatted': u'Noviembre 2016', u'month': u'11', u'year': 2016},
#    u'isTextTruncated': False,
#    u'partner': {u'id': 452,
#     u'name': u'Hoteles.com',
#     u'urls': {u'logo': {u'title': u'Opini\xf3n aut\xe9ntica de',
#       u'url': u'//ie2.trivago.com/images/layoutimages/Rating/Partner/452_mx.png'},
#      u'web': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:KtS/rK4VpwVQNVRBBGIIpLNVwNNRIwnttVt3ItQpVKI:CLVtuGRQKAV:?oVAuoSF/Gn8?M8RyJRFyMNM/ItpezrBnDtkuL3neJQpFw7ZwMIQYsVgNISVDJ4QwFnkKLJMCs8oJVn/zL4pVxOpotxgLxMxDNSpJGxZHxwVYELMg?OJ7uMINKtkJK3nVttJUx8t%mMoKxDNSpVNMUDNNMAFSjIVVIMCxINxMAwrr/Nxn:?I4Q1Jn:0M7VHxNnHM8MuJRYKVuNuGtout2VVsMQLQtNvJeVJJnE::SEJQnkHxI:yJ8EuVQpfKlJoK4Stw8EexV:?Ix/IVNW?Q2NxNKUBHQSJVLWKItoJL3pJxMF5D2x6ttM9txNGtSkCINBSGSnusN3LLNF9:w:/sxEGuRE9sMgNx3R:JIAuIRNzQVINVnY1xnBotnpLItoJzrN4F8xtDmV6xJABJttuxMJHVJ/GVM3LJQQ/VVkINnFMEtFpM3QHLIxgHRJFuRA/oKxEQ1SVGNjsISoJENMVVt4rH8%lK%lK'}},
#    u'sentiment': 3,
#    u'text': u'Hotel ideal. C\xe9ntrico y con buena conexi\xf3n de trasporte p\xfablico (metro y l\xedneas de bus) personal muy amable. Habitaci\xf3n amplia con dos camas grandes, agua de cortes\xeda y amenidades muy completas (kit relajacion, gel, acondicionadores,...)',
#    u'title': u'Para repetir.',
#    u'type': u'scaled'},
#   {u'author': None,
#    u'date': {u'formatted': u'Octubre 2016', u'month': u'10', u'year': 2016},
#    u'isTextTruncated': False,
#    u'partner': {u'id': 452,
#     u'name': u'Hoteles.com',
#     u'urls': {u'logo': {u'title': u'Opini\xf3n aut\xe9ntica de',
#       u'url': u'//ie2.trivago.com/images/layoutimages/Rating/Partner/452_mx.png'},
#      u'web': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:KtS/rK4VpwVQNVRBBGIIpLNVwNNRIwnttVt3ItQpVKI:CLVtuGRQKAV:?oVAuoSF/Gn8?M8RyJRFyMNM/ItpezrBnDtkuL3neJQpFw7ZwMIQYsVgNISVDJ4QwFnkKLJMCs8oJVn/zL4pVxOpotxgLxMxDNSpJGxZHxwVYELMg?OJ7uMINKtkJK3nVttJUx8t%mMoKxDNSpVNMUDNNMAFSjIVVIMCxINxMAwrr/Nxn:?I4Q1Jn:0M7VHxNnHM8MuJRYKVuNuGtout2VVsMQLQtNvJeVJJnE::SEJQnkHxI:yJ8EuVQpfKlJoK4Stw8EexV:?Ix/IVNW?Q2NxNKUBHQSJVLWKItoJL3pJxMF5D2x6ttM9txNGtSkCINBSGSnusN3LLNF9:w:/sxEGuRE9sMgNx3R:JIAuIRNzQVINVnY1xnBotnpLItoJzrN4F8xtDmV6xJABJttuxMJHVJ/GVM3LJQQ/VVkINnFMEtFpM3QHLIxgHRJFuRA/oKxEQ1SVGNjsISoJENMVVt4rH8%lK%lK'}},
#    u'sentiment': 3,
#    u'text': u'Me ha gustado mucho, el personal del hotel muy amable y la habitaci\xf3n espaciosa y confortable, me ha impresionado los detalles de la habitaci\xf3n.',
#    u'title': u'Hotel muy limpio y c\xf3modo',
#    u'type': u'scaled'},
#   {u'author': None,
#    u'date': {u'formatted': u'Octubre 2016', u'month': u'10', u'year': 2016},
#    u'isTextTruncated': False,
#    u'partner': {u'id': 406,
#     u'name': u'Expedia',
#     u'urls': {u'logo': {u'title': u'Opini\xf3n verificada de',
#       u'url': u'//ie1.trivago.com/images/layoutimages/Rating/Partner/406_mx.png'},
#      u'web': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:HVS/rK4VpwVQNVRBBGIIpLNVwNNRIwntxtt3ItQpVKI:CLVtuGeFVxOABJuMJJPJpx4:&IRIuJSVFM4ItQnINCeQoxMB7MnjJJxjBJuNFuSJNINFPQIJxQV8JVw4KNJVIxMAIuMAxw8Amx4EpIIUxJ4Y:M7VGAL:sHOAzLNELIt/msNoJVmgwN1MtNxk:K6Qzu8Y0INBSQJSxQLftL6Rosx8sxGJoK4Rsw8EexI:?IxWItQQHVxVGA6RSsLR4BPk9oLphymFRC8gvFHVnzLJq?LQ4/6FTplBgrLIWF6xUQ3eGrxNLKV/&xMF5EmVgs4MxJtIpKPtTplBRy6oUAeQutQAQr7B?KQoIExErVSBVx4QBQ8pFxtE/:QxHx3ktsn8JVV3/tSNxuMNPVNxVrJAVN7WBVNVGtQpFVNnHQneQtMEUM8IsxxtVKHgoN4NCL8RnEnQ&?R/yx7FzV3tlGQnHwSxw'}},
#    u'sentiment': 3,
#    u'text': u'El hotel esta completamente nuevo o reformado con materiales y acabados de alta calidad. Los empleados son muy amables y la limpieza es buena. Tiene categoria para ser un 5 estrellas',
#    u'title': u'Impecable, sin duda un gran descubrimiento',
#    u'type': u'scaled'}],
#  u'id': u'6795',
#  u'metaReviews': {u'negative': [], u'positive': []},
#  u'ratingSummary': {u'hasAdvertiserRatings': True,
#   u'hasQualityTests': False,
#   u'hotelAwards': [],
#   u'isInEu': True,
#   u'partnerReviewCount': 3585,
#   u'ratingAspects': [{u'index': 5,
#     u'percentage': 87,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'facilities'},
#    {u'index': 3,
#     u'percentage': 75,
#     u'ratingText': u'\xa1Buena!',
#     u'type': u'breakfast'},
#    {u'index': 5,
#     u'percentage': 88,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'service'},
#    {u'index': 5,
#     u'percentage': 91,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'cleanliness'},
#    {u'index': 5,
#     u'percentage': 91,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'comfort'},
#    {u'index': 5,
#     u'percentage': 85,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'food_and_drinks'},
#    {u'index': 5,
#     u'percentage': 85,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'location'},
#    {u'index': 5,
#     u'percentage': 88,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'hotel_condition'},
#    {u'index': 4,
#     u'percentage': 83,
#     u'ratingText': u'\xa1Muy buena!',
#     u'type': u'value_for_money'},
#    {u'index': 5,
#     u'percentage': 90,
#     u'ratingText': u'\xa1Excelente!',
#     u'type': u'room'}],
#   u'ratingIndexLink': u'https://www.trivago.es/static/rating-index',
#   u'reviewPartners': [{u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:HVS/rK4VpwtIpH4MtMSk?VInExIk&Qe:uN84BMJxJun/rJepLHSRpNNpotIAwpJE::RVHAMjtNtfJGRftVMeuxepIxMB7LIkVx5QMuNFJutE::n4&INpHxL/urneHLVINCRIHtMoDrSF:x4xBJuMuJVopGNMGrnWttnE1DxY/p7W:MIMut2Vsw8BHz8/Jp7FtuxALpng?Gn8HxwtuQ3eG98J9D4W9KtVDyVj9HtABJKExMIVorIQJJQMGtnE3F5S99uJ2DNe6Bm8RC1o%mIs5Z2:OBU/6Q8plt1AP7RAw4yCPM3:u7rsRt?MVJKHneVxOp7:OYyJnf:M83&BL7RAwxUDLISItoJMtFpM48Kw8EexeExJVAuISFzQV4QVnY1Q3BVtI8/LVINrekVItELrGtIttM&txBrwNFpQ7pJJSjHwnBQtnSrQO8uMeQKNJpLFnjuIxkBG5BPMRQ5tIkuMS7JJPEzNSZBVQ/%lK',
#     u'id': 406,
#     u'name': u'Expedia',
#     u'ratingPercentage': 90},
#    {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:KtS/rK4VpwtIpH4MtMSk?VInExIk&Qe:uN84BMJINun/rJepLHSRpNNpoM4t8MItYINFPIRZAG8jVN8AtQnZxM4jutm/lylEkHSpBuOFJVQpHrtAxQwfCHxVJLSoVIt/msMIzVx7tw8BHN7WBVIAwox/:sIBxNtSxQMIzIJZL:KSRE2kYEGELrQ:/HRJFuRAJJ6BDQ2gRFtSxQNMuIQoGtx8mLI/uxMF5rQ/Vx4:?otowMIV&NloHQ38ttnBrNSYMtQpHGIJuEtNuL7QKBJM0M4xtJPI9N7VHxnU3xIJQtJZKM7ZGMJJuJmkMyVj9HQIBJKEQMIVotIQMG7nQE8xuAQM0rVIMCxIutR/JH4BVxOpW:6xJJnJ:VnpHHSeHxwVBNRg9sM/:MNeOB8frr8N0xeY0KtouKnA/INELMQ7uIntJVLWNN4RHtMMutR/lyHAOttJU:PxxJJE:N4FxMNMHNxFGISjsVt3NsM:IxnFXK3frNxBzx5ZzQ8pKVNeRFtfQz8MyNMYQVRJRM4/urJQt',
#     u'id': 452,
#     u'name': u'Hoteles.com',
#     u'ratingPercentage': 92},
#    {u'advertiserLink': u'',
#     u'id': 71,
#     u'name': u'Splendia',
#     u'ratingPercentage': 92},
#    {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMoMxnJHHn4AxeAQItAGwMBDrNnLxVNstMAJNVFJMnFHLIJxMIV&MeVJMI:&p3AuoeE::e/KMt:CHQnFNSjFtRSrL47pMIELrr:pHSpBunWYu7BDrVFxMQRxN7xyNNY9?OS:Gtp&xMB3Ie8Vx5Nxs3WLwu8GtRe/HSngQ3Ntr3Z9sNN9MQtHNJpLt8BMQJIytKZNuSN&tI/xy8oNISnJs6Y6I8/%mMLJexIJNNL1E9JM:tx8t%lK',
#     u'id': 57,
#     u'name': u'Holidaycheck',
#     u'ratingPercentage': 93},
#    {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMMzt8/rK4VpwtIpH4MtMSk?VInExIk&Qe:uN84BNeRMun/rJepLHSRpNNpoM4t8MItYINFPMxjtsNMVIQjMtx8:xeNoKNxVDV39NM/Ix8VJJPJHrnQxL4:uG7JJVL3MVnIMCtJKJ3NwL3VxDSFHtw4Eu7BDrxVHxN7rMNMGNtZL:JnLsQoJVe8KBI39NM/IM4t3JnV?INELM87xGS:NQ3RnNIINreZwy3JVNJ:VJxpHtVAwoVoDNSp&MSxgHNjLKSYLIt/msNoJVe/LKI3xDR/GVSQNxQoDN1xHxJSxQnA1VnStN4INCRIHtMoLrQ:sJxJMQ64wQNWHVVIxQwexQtQut3nlNJ:rsRoJERArr8pVx4QGV7W%mMwQpAsJQVJQMBHNxwQ3RnNVINreeKKGkHLex/NMe&9J:JJ6A:INELMRnzDxEzJ7nwVVIMCV/JLI/HLIk0JQIBJtNtVQZSrItQHRRztnE3M83rsx8?LI/uJ8xVstxJHweDQ7WxQNkFrRVGA8nBHSMFLt3MtxBrVMIGVxEMGGnxH7t/Q7JJ?Q8BtISxuPRStMEUM8IsxxtVKHNoMtx&L4F%lK',
#     u'id': 383,
#     u'name': u'Atrapalo',
#     u'ratingPercentage': 83},
#    {u'advertiserLink': u'',
#     u'id': 0,
#     u'name': u'Otras fuentes',
#     u'ratingPercentage': 85}],
#   u'reviewRating': {u'index': 5, u'percentage': 89}}}

# %%
data_json.keys()
# Out:
# [u'metaReviews', u'ratingSummary', u'id', u'hydraReviews']

# %%
data_json["ratingSummary"]["ratingAspects"][0].keys()
# Out:
# [u'ratingText', u'index', u'percentage', u'type']

# %%
data_json["ratingSummary"]
# Out:
# {u'hasAdvertiserRatings': True,
#  u'hasQualityTests': False,
#  u'hotelAwards': [],
#  u'isInEu': True,
#  u'partnerReviewCount': 3585,
#  u'ratingAspects': [{u'index': 5,
#    u'percentage': 87,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'facilities'},
#   {u'index': 3,
#    u'percentage': 75,
#    u'ratingText': u'\xa1Buena!',
#    u'type': u'breakfast'},
#   {u'index': 5,
#    u'percentage': 88,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'service'},
#   {u'index': 5,
#    u'percentage': 91,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'cleanliness'},
#   {u'index': 5,
#    u'percentage': 91,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'comfort'},
#   {u'index': 5,
#    u'percentage': 85,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'food_and_drinks'},
#   {u'index': 5,
#    u'percentage': 85,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'location'},
#   {u'index': 5,
#    u'percentage': 88,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'hotel_condition'},
#   {u'index': 4,
#    u'percentage': 83,
#    u'ratingText': u'\xa1Muy buena!',
#    u'type': u'value_for_money'},
#   {u'index': 5,
#    u'percentage': 90,
#    u'ratingText': u'\xa1Excelente!',
#    u'type': u'room'}],
#  u'ratingIndexLink': u'https://www.trivago.es/static/rating-index',
#  u'reviewPartners': [{u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:HVS/rK4VpwtIpH4MtMSk?VInExIk&Qe:uN84BMJxJun/rJepLHSRpNNpotIAwpJE::RVHAMjtNtfJGRftVMeuxepIxMB7LIkVx5QMuNFJutE::n4&INpHxL/urneHLVINCRIHtMoDrSF:x4xBJuMuJVopGNMGrnWttnE1DxY/p7W:MIMut2Vsw8BHz8/Jp7FtuxALpng?Gn8HxwtuQ3eG98J9D4W9KtVDyVj9HtABJKExMIVorIQJJQMGtnE3F5S99uJ2DNe6Bm8RC1o%mIs5Z2:OBU/6Q8plt1AP7RAw4yCPM3:u7rsRt?MVJKHneVxOp7:OYyJnf:M83&BL7RAwxUDLISItoJMtFpM48Kw8EexeExJVAuISFzQV4QVnY1Q3BVtI8/LVINrekVItELrGtIttM&txBrwNFpQ7pJJSjHwnBQtnSrQO8uMeQKNJpLFnjuIxkBG5BPMRQ5tIkuMS7JJPEzNSZBVQ/%lK',
#    u'id': 406,
#    u'name': u'Expedia',
#    u'ratingPercentage': 90},
#   {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:KtS/rK4VpwtIpH4MtMSk?VInExIk&Qe:uN84BMJINun/rJepLHSRpNNpoM4t8MItYINFPIRZAG8jVN8AtQnZxM4jutm/lylEkHSpBuOFJVQpHrtAxQwfCHxVJLSoVIt/msMIzVx7tw8BHN7WBVIAwox/:sIBxNtSxQMIzIJZL:KSRE2kYEGELrQ:/HRJFuRAJJ6BDQ2gRFtSxQNMuIQoGtx8mLI/uxMF5rQ/Vx4:?otowMIV&NloHQ38ttnBrNSYMtQpHGIJuEtNuL7QKBJM0M4xtJPI9N7VHxnU3xIJQtJZKM7ZGMJJuJmkMyVj9HQIBJKEQMIVotIQMG7nQE8xuAQM0rVIMCxIutR/JH4BVxOpW:6xJJnJ:VnpHHSeHxwVBNRg9sM/:MNeOB8frr8N0xeY0KtouKnA/INELMQ7uIntJVLWNN4RHtMMutR/lyHAOttJU:PxxJJE:N4FxMNMHNxFGISjsVt3NsM:IxnFXK3frNxBzx5ZzQ8pKVNeRFtfQz8MyNMYQVRJRM4/urJQt',
#    u'id': 452,
#    u'name': u'Hoteles.com',
#    u'ratingPercentage': 92},
#   {u'advertiserLink': u'',
#    u'id': 71,
#    u'name': u'Splendia',
#    u'ratingPercentage': 92},
#   {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMoMxnJHHn4AxeAQItAGwMBDrNnLxVNstMAJNVFJMnFHLIJxMIV&MeVJMI:&p3AuoeE::e/KMt:CHQnFNSjFtRSrL47pMIELrr:pHSpBunWYu7BDrVFxMQRxN7xyNNY9?OS:Gtp&xMB3Ie8Vx5Nxs3WLwu8GtRe/HSngQ3Ntr3Z9sNN9MQtHNJpLt8BMQJIytKZNuSN&tI/xy8oNISnJs6Y6I8/%mMLJexIJNNL1E9JM:tx8t%lK',
#    u'id': 57,
#    u'name': u'Holidaycheck',
#    u'ratingPercentage': 93},
#   {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMMzt8/rK4VpwtIpH4MtMSk?VInExIk&Qe:uN84BNeRMun/rJepLHSRpNNpoM4t8MItYINFPMxjtsNMVIQjMtx8:xeNoKNxVDV39NM/Ix8VJJPJHrnQxL4:uG7JJVL3MVnIMCtJKJ3NwL3VxDSFHtw4Eu7BDrxVHxN7rMNMGNtZL:JnLsQoJVe8KBI39NM/IM4t3JnV?INELM87xGS:NQ3RnNIINreZwy3JVNJ:VJxpHtVAwoVoDNSp&MSxgHNjLKSYLIt/msNoJVe/LKI3xDR/GVSQNxQoDN1xHxJSxQnA1VnStN4INCRIHtMoLrQ:sJxJMQ64wQNWHVVIxQwexQtQut3nlNJ:rsRoJERArr8pVx4QGV7W%mMwQpAsJQVJQMBHNxwQ3RnNVINreeKKGkHLex/NMe&9J:JJ6A:INELMRnzDxEzJ7nwVVIMCV/JLI/HLIk0JQIBJtNtVQZSrItQHRRztnE3M83rsx8?LI/uJ8xVstxJHweDQ7WxQNkFrRVGA8nBHSMFLt3MtxBrVMIGVxEMGGnxH7t/Q7JJ?Q8BtISxuPRStMEUM8IsxxtVKHNoMtx&L4F%lK',
#    u'id': 383,
#    u'name': u'Atrapalo',
#    u'ratingPercentage': 83},
#   {u'advertiserLink': u'',
#    u'id': 0,
#    u'name': u'Otras fuentes',
#    u'ratingPercentage': 85}],
#  u'reviewRating': {u'index': 5, u'percentage': 89}}

# %%
hotelId = data_json["id"]
rats = []

for rating in data_json["ratingSummary"]["ratingAspects"]:
    print rating
# Out:
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 87, u'type': u'facilities'}
# {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 75, u'type': u'breakfast'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 88, u'type': u'service'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 91, u'type': u'cleanliness'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 91, u'type': u'comfort'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 85, u'type': u'food_and_drinks'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 85, u'type': u'location'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 88, u'type': u'hotel_condition'}
# {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 83, u'type': u'value_for_money'}
# {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 90, u'type': u'room'}

# %%
data_json["ratingSummary"]["reviewRating"]
# Out:
# {u'index': 5, u'percentage': 89}

# %% [markdown]
# ####  Attributes of interest
#
#
#     data_json["ratingSummary"]["partnerReviewCount"] # number of total reviews from partners
#     data_json["ratingSummary"]["reviewPartners"] # list, each pos dict with dict {"name", "id", "ratingPercentage"}
#     data_json["ratingSummary"]["reviewRating"] # final hotel rating
#     data_json["ratingSummary"]["hasQualityTests"] # extra info
#     data_json["ratingSummary"]["ratingAspects"] # important, ratings of each hotel aspects

# %% [markdown]
# ## Complete Info

# %%
url2 = "https://www.trivago.es/api/v1/_cache/accommodation/99027/complete-info.json"

params2 = dict(requestId="v11_03_1_ae_es_ES_ES")

r = requests.get(url = url2, params = params2)

# %%
data = json.loads(r.text)
data
# Out:
# {u'accommodation': {u'address': {u'country': u'Espa\xf1a',
#    u'locality': u'Sitges',
#    u'postalCode': u'08870',
#    u'street': u'Jesus, 16'},
#   u'centroid': {u'latitude': 41.237034, u'longitude': 1.81022},
#   u'contact': {u'email': u'sitgespark@mediumhoteles.com',
#    u'fax': u'+34(93)8940839',
#    u'phone': u'+34(93)8940250',
#    u'web': u'http://www.mediumhoteles.com/es/espana/sitges/centro/hotel-medium-sitges-park'},
#   u'hotelStarRating': {u'isSuperior': False, u'starCount': 3},
#   u'id': 99027,
#   u'isPremiumPartner': False,
#   u'name': u'Medium Sitges Park',
#   u'reviewRating': {u'index': 4, u'percentage': 81},
#   u'types': [u'Hotel']},
#  u'adequateFor': [u'Lunas de miel', u'Gay friendly', u'Deportes acu\xe1ticos'],
#  u'amenities': {u'groupedFeatures': [{u'features': [{u'title': u'Aparcamiento'},
#      {u'title': u'Ascensor'},
#      {u'title': u'Bar del hotel'},
#      {u'title': u'Bar en la piscina'},
#      {u'title': u'Conserje'},
#      {u'title': u'Lavander\xeda'},
#      {u'title': u'Mascotas permitidas'},
#      {u'title': u'Piscina exterior'},
#      {u'title': u'Recepci\xf3n 24 horas'},
#      {u'title': u'Restaurante'},
#      {u'title': u'Sala de conferencias'},
#      {u'title': u'Sombrillas'},
#      {u'title': u'Terraza'},
#      {u'title': u'Tumbonas'},
#      {u'title': u'Wi-Fi en el vest\xedbulo'},
#      {u'title': u'Wi-Fi gratis en el vest\xedbulo'}],
#     u'title': u'Instalaciones y servicios'},
#    {u'features': [{u'title': u'Aire acondicionado'},
#      {u'title': u'Ba\xf1o con ba\xf1era'},
#      {u'title': u'Ba\xf1o con ducha'},
#      {u'title': u'Caja fuerte en la hab.'},
#      {u'title': u'Calefacci\xf3n central'},
#      {u'title': u'Escritorio'},
#      {u'title': u'Habitaci\xf3n con Wi-Fi gratis'},
#      {u'title': u'Internet'},
#      {u'title': u'Secador de pelo'},
#      {u'title': u'Tel\xe9fono'},
#      {u'title': u'Televisi\xf3n por cable'},
#      {u'title': u'Televisi\xf3n por sat\xe9lite'},
#      {u'title': u'Televisor'},
#      {u'title': u'Wi-Fi en la habitaci\xf3n'}],
#     u'title': u'Equipamiento de la habitaci\xf3n'},
#    {u'features': [{u'title': u'Cunas para beb\xe9s y ni\xf1os'}],
#     u'title': u'Viajeros con ni\xf1os'},
#    {u'features': [{u'comment': u'a 5 km', u'title': u'Alquiler de barcos'},
#      {u'comment': u'a 10 km ', u'title': u'Alquiler de bicicletas'},
#      {u'comment': u'a 5 km', u'title': u'Buceo'},
#      {u'comment': u'a 5 km', u'title': u'Navegaci\xf3n'},
#      {u'comment': u'a 5 km', u'title': u'Senderismo'},
#      {u'comment': u'a 5 km', u'title': u'Surf'}],
#     u'title': u'Instalaciones deportivas'}],
#   u'topFeatures': [{u'iconName': u'wifi',
#     u'isAvailable': True,
#     u'isFreeOfCharge': True,
#     u'title': u'Wi-Fi (vest\xedbulo)'},
#    {u'iconName': u'wifi',
#     u'isAvailable': True,
#     u'isFreeOfCharge': True,
#     u'title': u'Wi-Fi (habitaci\xf3n)'},
#    {u'iconName': u'pool',
#     u'isAvailable': True,
#     u'isFreeOfCharge': False,
#     u'title': u'Piscina'},
#    {u'iconName': u'spa',
#     u'isAvailable': False,
#     u'isFreeOfCharge': False,
#     u'title': u'Spa'},
#    {u'iconName': u'parking',
#     u'isAvailable': True,
#     u'isFreeOfCharge': False,
#     u'title': u'Parking'},
#    {u'iconName': u'pet',
#     u'isAvailable': True,
#     u'isFreeOfCharge': False,
#     u'title': u'Mascotas permitidas'},
#    {u'iconName': u'ac',
#     u'isAvailable': True,
#     u'isFreeOfCharge': False,
#     u'title': u'Aire acondicionado'},
#    {u'iconName': u'restaurant',
#     u'isAvailable': True,
#     u'isFreeOfCharge': False,
#     u'title': u'Restaurante'},
#    {u'iconName': u'bar',
#     u'isAvailable': True,
#     u'isFreeOfCharge': False,
#     u'title': u'Bar del hotel'},
#    {u'iconName': u'gym',
#     u'isAvailable': False,
#     u'isFreeOfCharge': False,
#     u'title': u'Gimnasio'}]},
#  u'checkInOutTimes': {u'checkIn': u'13:00', u'checkOut': u'12:00'},
#  u'description': {u'isFreelancerSource': False,
#   u'text': u'El Hotel Medium Sitges Park est\xe1 situado en el pintoresco y animado casco antiguo de Sitges, en un edificio modernista de finales del siglo XIX. La reforma integral respeta el estilo propio del hotel, introduciendo en el dise\xf1o elementos de frescura y tonos mediterr\xe1neos. Su especial ubicaci\xf3n permite acceder a todos los puntos de inter\xe9s en menos de cinco minutos de paseo ya que se encuentra junto a la playa, los locales de ocio y la estaci\xf3n de tren. Dispone de restaurante, bar y jard\xedn con piscina. Las habitaciones son amplias y equipadas con todas las facilidades para vivir una estancia confortable. '},
#  u'hotelGatewayLink': u'https://www.trivago.es/hotelgateway/',
#  u'roomTypes': [{u'availableBeds': [u'Cama de matrimonio',
#     u'Dos camas individuales'],
#    u'features': [u'Ba\xf1o con ba\xf1era',
#     u'Ba\xf1o con ducha',
#     u'Caja fuerte en la hab.',
#     u'Escritorio',
#     u'Minibar',
#     u'TV de pantalla plana'],
#    u'title': u'Habitaci\xf3n est\xe1ndar '}]}

# %%
data["accommodation"]["types"]
# Out:
# [u'Hotel']

# %% [markdown]
# #### Attributes of interest
#
#     data["accommodation"]["address"]["postalCode"]
#     data["accommodation"]["address"]["street"]
#     data["accommodation"]["centroid"]["latitude"]
#     data["accommodation"]["centroid"]["longitude"]
#     data["accommodation"]["contact"]["email"]
#     data["accommodation"]["contact"]["fax"]
#     data["accommodation"]["contact"]["phone"]
#     data["accommodation"]["contact"]["web"]
#     data["accommodation"]["hotelStarRating"]["starCount"]
#     data["accommodation"]["isPremiumPartner"]
#     data["accommodation"]["types"]
#     data["accommodation"]["name"]
#
#     data["roomTypes"][0]["availableBeds"] # list
#     data["adequateFor"] # list
#
#     data["amenities"]["topFeatures"] # list, each pos interesting: {"isAvailable","isFreeOfCharge","title"}

# %% [markdown]
# ## Get ids of all hotels in City

# %%
# url = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-03-26&aDateRange%5Bdep%5D=2017-03-27&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iLimit=25&iIncludeAll=1&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"
# u2 = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-03-26&aDateRange%5Bdep%5D=2017-03-27&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iOffset=0&iLimit=25&iIncludeAll=1&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"

# params = dict(iOffset=0) # indicates page of search, it goes from 0 to 25 (page 1). 25 to 50 (page 2), etc...

# page = requests.get(u2)

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.webdriver.support.ui import WebDriverWait

# url = "https://www.trivago.es/?cpt=3196503&iRoomType=7&iPathId=31965&aDateRange%5Barr%5D=2017-04-02&aDateRange%5Bdep%5D=2017-04-03&iGeoDistanceItem=0&iViewType=0&bIsSeoPage=false&bIsSitemap=false&"  

# driver = webdriver.Chrome() 
# driver.get(url)
# WebDriverWait(driver,5)
# xpath = "//script"
# daily = driver.find_element_by_xpath(xpath)

# %%
import Cookie
import time

def parse_trivago_cookies(r):
    cookies = Cookie.SimpleCookie()
    cookies.load(r.headers['Set-Cookie'])
    
    return cookies

def get_trivago_cookies():
    headers = {
        'cache-control': 'max-age=0',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
    }
    
    r = requests.get("https://www.trivago.es", headers=headers)
    return parse_trivago_cookies(r)


def do_trivago_request(url, cookies):
    headers = {
        'cache-control': 'max-age=0',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
        'cookie': ''.join([name + '=' + morsel.coded_value for name, morsel in cookies.items()])
    }
    return requests.get(url, headers=headers)

def poll_until_not_empty(url, cookies, xpath):
    r = do_trivago_request(url, cookies)
    cookies = parse_trivago_cookies(r)
    
    page = html.fromstring(r.text)
    element = page.xpath(xpath)[0]
    
    if element.getchildren():
        return element, r
    
    print '[EMPTY] Retrying in 1s'
    time.sleep(1)
    return poll_until_not_empty(url,cookies, xpath)

# %%
li = ol.getchildren()[0]
li.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-713c362e14f9> in <module>()
# ----> 1 li = ol.getchildren()[0]
#       2 li.values()
#
# NameError: name 'ol' is not defined

# %%
cookies = get_trivago_cookies()
url = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-04-02&aDateRange%5Bdep%5D=2017-04-03&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iOffset=0&iLimit=25&iIncludeAll=0&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"

xpath = "/html/body/div/main/div//ol"

ol,r = poll_until_not_empty(url, cookies, xpath)
print ol.getchildren()
r.text
# Out:
# [EMPTY] Retrying in 1s
# [<Element li at 0x10a5db730>, <Element li at 0x10a5db5d0>, <Element li at 0x10c98f260>, <Element li at 0x10c98f208>, <Element li at 0x10c98f100>, <Element li at 0x10c98f158>, <Element li at 0x10c98f578>]
# u'<!DOCTYPE html><html lang="es" prefix="og: http://ogp.me/ns#"><head><!--\n    Want to get paid to dissect our code?\n    We\'re hiring developers: http://company.trivago.com/jobs\n--><script type="text/javascript">\nvar domStart = Math.round(new Date().getTime()), serverTimestamp = 1489257893972; window.webpackPublicPath = \'//jse.trivago.com/_assets/osp/vAssets/\'; </script><meta charset="utf-8"><meta name="msvalidate.01" content="8C7A5F9D418AC51C45B7BDE53601FCAC" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta name="google" content="notranslate" /><title data-default="trivago.es - Compara entre miles de ofertas y elige el hotel ideal al mejor precio" data-title="9617 Hoteles en Barcelona (Provincia) -78% | Encuentra tu hotel barato - trivago.es">9617 Hoteles en Barcelona (Provincia) -78% | Encuentra tu hotel barato - trivago.es</title><meta name="description" content="Busca y compara 9617 hoteles en Barcelona (Provincia). Compara precios a trav\xe9s de 250 p\xe1ginas de reserva. Ahorra hasta un 78%. \xbfHoteles en Barcelona (Provincia)? - trivago!" /><meta property="og:title" content="9617 Hoteles en Barcelona (Provincia) -78% | Encuentra tu hotel barato - trivago.es" /><meta property="og:description" content="Busca y compara 9617 hoteles en Barcelona (Provincia). Compara precios a trav\xe9s de 250 p\xe1ginas de reserva. Ahorra hasta un 78%. \xbfHoteles en Barcelona (Provincia)? - trivago!" /><meta property="og:image" content="//ie1.trivago.com/images/layoutimages/mars/logo_ci/logo@2x.png" /><meta property="og:url" content="https://www.trivago.es" /><meta name="robots" content="index,follow" /><link rel="canonical" href="https://www.trivago.es/barcelona-provincia-344066/hotel" /><link rel="publisher" href="https://plus.google.com/104932839474048215618" /><meta property="fb:page_id" content="137633439645541" /><meta name="p:domain_verify" content="7dfe2330e1dae0a6aa7f9479e616b6f9" /><meta property="og:type" content="website" /><meta property="og:site_name" content="trivago" /><meta name="trv-localization" data-locale="ES" data-lang="es" data-datetype="es" content="ES" /><meta name="format-detection" content="telephone=no"><link rel="profile" href="http://a9.com/-/spec/opensearch/1.1/"><link rel="search" type="application/opensearchdescription+xml" href="https://www.trivago.es/search/v11_03_1ai_cache/opensearch_es-ES-ES.xml" title="trivago" /><link rel="shortcut icon" href="//ie2.trivago.com/images/layoutimages/favicon_moon/favicon_16x16.ico"/><link rel="dns-prefetch" href="//jse.trivago.com"/><link rel="dns-prefetch" href="//imgec.trivago.com"/><link rel="dns-prefetch" href="https://dus.trivago.com"/><link rel="dns-prefetch" href="//apis.google.com"/><link rel="dns-prefetch" href="//ie1.trivago.com/images"/><link rel="dns-prefetch" href="//ie2.trivago.com/images"/><link rel="stylesheet" href="/search/pageCheck" /><link rel="stylesheet" href="//jse.trivago.com/_assets/osp/vAssets/main.84d9c6bd163b07b08165.ec.css" /><link rel="stylesheet" href="//jse.trivago.com/_assets/osp/vAssets/addon_css.22063f79d24dde7701e9.ec.css" /><link rel="preload" href="//jse.trivago.com/_assets/osp/vAssets/vendor.06439e22db7d52622490.js" as="script"><link rel="preload" href="//jse.trivago.com/_assets/osp/vAssets/pricesearch.a9600122dc67f063b978.js" as="script"><script type="text/javascript"><!--//--><![CDATA[//><!--\n/*! modernizr 3.3.1 (Custom Build) | MIT *\n * https://modernizr.com/download/?-backgroundsize-flexbox-svg-domprefixes-setclasses-testallprops-testprop !*/\n!function(e,n,t){function r(e,n){return typeof e===n}function s(){var e,n,t,s,o,i,a;for(var l in w)if(w.hasOwnProperty(l)){if(e=[],n=w[l],n.name&&(e.push(n.name.toLowerCase()),n.options&&n.options.aliases&&n.options.aliases.length))for(t=0;t<n.options.aliases.length;t++)e.push(n.options.aliases[t].toLowerCase());for(s=r(n.fn,"function")?n.fn():n.fn,o=0;o<e.length;o++)i=e[o],a=i.split("."),1===a.length?Modernizr[a[0]]=s:(!Modernizr[a[0] ...

# %%
for child in ol.getchildren():
    print child.values()
# Out:
# ['hotel item-order__list-item js_co_item', '0', '31965', '6738']
# ['hotel item-order__list-item js_co_item', '1', '31965', '6739']
# ['hotel item-order__list-item js_co_item', '2', '31965', '6743']
# ['item-order__list-item js_phantom_pain']
# ['hotel item-order__list-item js_co_item', '3', '31965', '6745']
# ['hotel item-order__list-item js_co_item', '4', '31965', '6748']
# ['hotel item-order__list-item js_co_item', '5', '31965', '6752']

# %%
url2 = "https://www.trivago.es/?iPathId=344066&bDispMoreFilter=false&aDateRange%5Barr%5D=2017-04-02&aDateRange%5Bdep%5D=2017-04-03&aCategoryRange=0%2C1%2C2%2C3%2C4%2C5&iRoomType=7&sOrderBy=relevance%20desc&aPartner=&aOverallLiking=1%2C2%2C3%2C4%2C5&iOffset=175&iLimit=25&iIncludeAll=0&bTopDealsOnly=false&iViewType=0&aPriceRange%5Bto%5D=0&aPriceRange%5Bfrom%5D=0&aGeoCode%5Blng%5D=2.188504&aGeoCode%5Blat%5D=41.482311&bIsSeoPage=false&aHotelTestClassifier=&bSharedRooms=false&bIsSitemap=false&rp=&cpt=34406603&iFilterTab=0&"
cookies = get_trivago_cookies()
# params = {}

ol2, r2 = poll_until_not_empty(url2,cookies,xpath)

print ol2.getchildren()
r2.text
# Out:
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [EMPTY] Retrying in 1s
# [<Element li at 0x10a5db730>, <Element li at 0x10a4ab6d8>, <Element li at 0x10c98fe10>, <Element li at 0x10c98f1b0>, <Element li at 0x10c98faa0>, <Element li at 0x10c98f050>, <Element li at 0x10c98ffc8>, <Element li at 0x10c98ff70>, <Element li at 0x10c9b40a8>, <Element li at 0x10c9b4f70>, <Element li at 0x10c9b4418>, <Element li at 0x10c9b49f0>, <Element li at 0x10c9b47e0>, <Element li at 0x10c9b4cb0>, <Element li at 0x10c9b4c58>, <Element li at 0x10c9b4ba8>, <Element li at 0x10c9b4c00>, <Element li at 0x10c9b4e10>, <Element li at 0x10c9b4e68>, <Element li at 0x10c9b4f18>, <Element li at 0x10c9b4838>, <Element li at 0x10c9b4af8>, <Element li at 0x10c9b46d8>, <Element li at 0x10c9b4998>, <Element li at 0x10c9b48e8>, <Element li at 0x10c9b4470>]
# u'<!DOCTYPE html><html lang="es" prefix="og: http://ogp.me/ns#"><head><!--\n    Want to get paid to dissect our code?\n    We\'re hiring developers: http://company.trivago.com/jobs\n--><script type="text/javascript">\nvar domStart = Math.round(new Date().getTime()), serverTimestamp = 1489258484759; window.webpackPublicPath = \'//jse.trivago.com/_assets/osp/vAssets/\'; </script><meta charset="utf-8"><meta name="msvalidate.01" content="8C7A5F9D418AC51C45B7BDE53601FCAC" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta name="google" content="notranslate" /><title data-default="trivago.es - Compara entre miles de ofertas y elige el hotel ideal al mejor precio" data-title="9617 Hoteles en Barcelona (Provincia) -78% | Encuentra tu hotel barato - trivago.es">9617 Hoteles en Barcelona (Provincia) -78% | Encuentra tu hotel barato - trivago.es</title><meta name="description" content="Busca y compara 9617 hoteles en Barcelona (Provincia). Compara precios a trav\xe9s de 250 p\xe1ginas de reserva. Ahorra hasta un 78%. \xbfHoteles en Barcelona (Provincia)? - trivago!" /><meta property="og:title" content="9617 Hoteles en Barcelona (Provincia) -78% | Encuentra tu hotel barato - trivago.es" /><meta property="og:description" content="Busca y compara 9617 hoteles en Barcelona (Provincia). Compara precios a trav\xe9s de 250 p\xe1ginas de reserva. Ahorra hasta un 78%. \xbfHoteles en Barcelona (Provincia)? - trivago!" /><meta property="og:image" content="//ie1.trivago.com/images/layoutimages/mars/logo_ci/logo@2x.png" /><meta property="og:url" content="https://www.trivago.es" /><meta name="robots" content="index,follow" /><link rel="canonical" href="https://www.trivago.es/barcelona-provincia-344066/hotel" /><link rel="publisher" href="https://plus.google.com/104932839474048215618" /><meta property="fb:page_id" content="137633439645541" /><meta name="p:domain_verify" content="7dfe2330e1dae0a6aa7f9479e616b6f9" /><meta property="og:type" content="website" /><meta property="og:site_name" content="trivago" /><meta name="trv-localization" data-locale="ES" data-lang="es" data-datetype="es" content="ES" /><meta name="format-detection" content="telephone=no"><link rel="profile" href="http://a9.com/-/spec/opensearch/1.1/"><link rel="search" type="application/opensearchdescription+xml" href="https://www.trivago.es/search/v11_03_1ai_cache/opensearch_es-ES-ES.xml" title="trivago" /><link rel="shortcut icon" href="//ie2.trivago.com/images/layoutimages/favicon_moon/favicon_16x16.ico"/><link rel="dns-prefetch" href="//jse.trivago.com"/><link rel="dns-prefetch" href="//imgec.trivago.com"/><link rel="dns-prefetch" href="https://dus.trivago.com"/><link rel="dns-prefetch" href="//apis.google.com"/><link rel="dns-prefetch" href="//ie1.trivago.com/images"/><link rel="dns-prefetch" href="//ie2.trivago.com/images"/><link rel="stylesheet" href="/search/pageCheck" /><link rel="stylesheet" href="//jse.trivago.com/_assets/osp/vAssets/main.808da5182bc7dba42cd7.ec.css" /><link rel="stylesheet" href="//jse.trivago.com/_assets/osp/vAssets/addon_css.dcd1746d83ed8891a6e9.ec.css" /><script type="text/javascript"><!--//--><![CDATA[//><!--\n/*! modernizr 3.3.1 (Custom Build) | MIT *\n * https://modernizr.com/download/?-backgroundsize-flexbox-svg-domprefixes-setclasses-testallprops-testprop !*/\n!function(e,n,t){function r(e,n){return typeof e===n}function s(){var e,n,t,s,o,i,a;for(var l in w)if(w.hasOwnProperty(l)){if(e=[],n=w[l],n.name&&(e.push(n.name.toLowerCase()),n.options&&n.options.aliases&&n.options.aliases.length))for(t=0;t<n.options.aliases.length;t++)e.push(n.options.aliases[t].toLowerCase());for(s=r(n.fn,"function")?n.fn():n.fn,o=0;o<e.length;o++)i=e[o],a=i.split("."),1===a.length?Modernizr[a[0]]=s:(!Modernizr[a[0]]||Modernizr[a[0]]instanceof Boolean||(Modernizr[a[0]]=new Boolean(Modernizr[a[0]])),Modernizr[a[0]][a[1]]=s),y.push((s?"":"no-")+a.join("-"))}}function o(e){var n=S.className,t=Modernizr._config.classPrefix||"";if(x&&(n= ...

# %%
xpath2 = "//*//div[3]/section/div/div/div/strong/text()"
xpath3= "/html/body/div/main/div//section/ol/li[2]//section[2]//strong/text()"
page = html.fromstring(r2.text)
element = page.xpath(xpath3)

print element[0]
print unicode(element[0], "utf-8")
# Out:
# ‎216 €
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-14fce6ef2674> in <module>()
#       5
#       6 print element[0]
# ----> 7 print unicode(element[0], "utf-8")
#
# TypeError: decoding Unicode is not supported

# %%
text = r2.text

# %%
def get_hotel_ids_prices(html_source):
    st = ""
    
    if len(html_source) > 0:
        
        for line in text.splitlines():
            if line.startswith("appConfig.initialValues"):
                st = line
                break
    
        st = st[26:]
        st = st[:len(st)-1]
        
        json_st = json.loads(st)
        hotel_ids = json_st["metadata"]["gtm"]["variables"]["itemIds"].split(",")
        hotel_prices = json_st["metadata"]["gtm"]["variables"]["itemRates"].split(",")
        
        return hotel_ids, hotel_prices

# %%
hotels_ids, hotels_prices = get_hotel_ids_prices(text)

for hotel_id in hotels_ids:
    print "Processing Hotel id", hotel_id
    url = "https://www.trivago.es/api/v1/_cache/accommodation/" + hotel_id + "/web34591/ratings.json?"
    params = dict(requestId="v11_03_1_ae_es_ES_ES")
    
    # info 1
    data = requests.get(url=url, params=params)
    data_json = json.loads(data.text)
    
    print "\t",data_json["ratingSummary"]["partnerReviewCount"] # number of total reviews from partners
    print "\t",data_json["ratingSummary"]["reviewPartners"] # list, each pos dict with dict {"name", "id", "ratingPercentage"}
    print "\t",data_json["ratingSummary"]["reviewRating"] # final hotel rating
    print "\t",data_json["ratingSummary"]["hasQualityTests"] # extra info
    print "\t",data_json["ratingSummary"]["ratingAspects"] # important, ratings of each hotel aspects
    
    # complete info
    url2 = "https://www.trivago.es/api/v1/_cache/accommodation/"+ hotel_id + "/complete-info.json"

    params2 = dict(requestId="v11_03_1_ae_es_ES_ES")

    r = requests.get(url = url2, params = params2)
    data_json2 = json.loads(r.text)
# Out:
# Processing Hotel id 152541
# 	247
# 	[{u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVM:KtS/rK4Vp
}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 90, u'type': u'location'}, {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 82, u'type': u'hotel_condition'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 86, u'type': u'value_for_money'}, {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 82, u'type': u'room'}]
# Processing Hotel id 2380456
# 	779
# 	[{u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMoMxnJHHn4AxeAQItAGwMBDrNnHQVJuQ3QrQxntV43Gr8tLNIBNL4tAGNp:tnAwpJE::RVHAMjtNtfELNApVMtCL4WuN4YEL4FVx5QMuNFJutZ1r4QxG8UHNQxuJRY9VRJ/A2WoItQCw8APKNUBJuQosJZBssg/JJxCGSV%mMtIpLM4xCxeWLKJnMGnMrJtf?J4EwMRQ5tIkuMS7JJPnzMNj:Vt4lz8tICtNELJxxJR/quMFJGNF/', u'ratingPercentage': 85, u'id': 57, u'name': u'Holidaycheck'}, {u'advertiserLink': u'', u'ratingPercentage': 92, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 5, u'percentage': 92}
# 	False
# 	[{u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 89, u'type': u'value_for_money'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 85, u'type': u'room'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 94, u'type': u'service'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 94, u'type': u'cleanliness'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 92, u'type': u'comfort'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 91, u'type': u'facilities'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 95, u'type': u'location'}]
# Processing Hotel id 1536695
# 	600
# 	[{u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMoMxnJHHn4AxeAQItAGwMBDrNnIxnZVQI8tQxntV43Gr8tLNIBNL4tAGNp:tnAwpJE::RVHAMjtNtfELNApVMtCL4WuN4YEL4FVx5QMuNFJutZ1r4QxG8UHNQxuJRY9VRJ/A2WoItQCw8APKNUBJuQosJZBssg/JJxCGSV%mMt3kELtnMxeWLKJnMGnMrJtf?J4EwMRQ5tIkuMS7JJPnzMNj:Vt4lz8tICtNELJxxJR/quMFJGNF/', u'ratingPercentage': 77, u'id': 57, u'name': u'Holidaycheck'}, {u'advertiserLink': u'', u'ratingPercentage': 76, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 3, u'percentage': 77}
# 	False
# 	[{u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 76, u'type': u'value_for_money'}, {u'ratingText': u'\u0e22\u0e01Muy buena!', u'index': 4, u'percentage': 83, u'type': u'service'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 78, u'type': u'cleanliness'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 74, u'type': u'comfort'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 75, u'type': u'facilities'}, {u'ratingText': u'\u0e22\u0e01Muy buena!', u'index': 4, u'percentage': 83, u'type': u'location'}]
# Processing Hotel id 675981
# 	2629
# 	[{u'advertiserLink': u'', u'ratingPercentage': 90, u'id': 57, u'name': u'Holidaycheck'}, {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMMGV8/rK4VpwtIpH4MtMSk?VInExIksun4QQxntV43MsMxQItNVLIxJwxZ:VSoJJ6oDNloxQLfQKSfIK8RQxMe:MSeBK4kxL4B0JQIBJuNPsN4CsIBVM8MBHJQuFuntQQJrH3/6MIFuM3R9H7WFun8Nt7/rINBPM8oDJ4QwFRUKsQFuK4RutR/LNtV/N7jBJKFNQ8QNrIe?I87rGSjyQ3eGVxZHNJ:ut2VsrNBGxeVytR/HxIY:NNxGVMYvISfHJ8jsVu8:L4F&MMS6yM:KzMBGxNBNx8FWr3QxuSRQ', u'ratingPercentage': 81, u'id': 317, u'name': u'Zoover'}, {u'advertiserLink': u'', u'ratingPercentage': 79, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 3, u'percentage': 79}
# 	False
# 	[{u'ratingText': u'\u0e22\u0e01Muy buena!', u'index': 4, u'percentage': 81, u'type': u'value_for_money'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage':
}, {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMoMxnJHHn4AxeAQHeIGwMBDrNnBQI8xu4:uN84BMtAtGtFJM4Qut33JNNEBJK:JJPIDNlpKMxkAG8jAK8UQwx/&KJN:ueQtw8AmGMe:x7YB&Q8?VISsIRjHMMVtLQ7tr6WiM3/uKQxVCt3EttNXsSfBQ8gSsVEoH8MGDVNQVIgMMnZ&Gtk&xnJHLIQAx4A:JINw?QpMV4tVIQRvHQENLSZB:w:tH2grKepwK3oVAReAx4WJt8%lK%lK', u'ratingPercentage': 83, u'id': 57, u'name': u'Holidaycheck'}, {u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMMGV8/rK4VpwtIpH4jsMSk?VInEw3WwxI4GIQYrKt:Kr8tLNIBNL4tAGNp:tnAwpJE::RVHAMY&HNVFMNjIsxW/xn4oK3/LGxfVMn:?owtpuSBHt3JNHSoAtnA1AQYNxxJMGr/uJ3tzN3j0GxBIKx/wtxfDN1pNGQMGtnE3JRnpx7tVM8oJVeQEHnnHHI:&oR/LQ88LrIgQJRnDHQgJVV3tr8N?KQoIExo9sNQKt8FFxMA/Jno?N7pGy87AJxxNNNYfrR/uMtoCEGEMGGnxH7t/Q7JJp88CVNexNQ%lK%lK', u'ratingPercentage': 83, u'id': 317, u'name': u'Zoover'}, {u'advertiserLink': u'', u'ratingPercentage': 80, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 4, u'percentage': 81}
# 	False
# 	[{u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 81, u'type': u'value_for_money'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 79, u'type': u'room'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 88, u'type': u'service'}, {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 83, u'type': u'cleanliness'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 77, u'type': u'comfort'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 78, u'type': u'food_and_drinks'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 76, u'type': u'facilities'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 86, u'type': u'location'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 76, u'type': u'hotel_condition'}]
# Processing Hotel id 2326388
# 	197
# 	[{u'advertiserLink': u'', u'ratingPercentage': 73, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 2, u'percentage': 73}
# 	False
# 	[{u'ratingText': u'Aceptable', u'index': 2, u'percentage': 74, u'type': u'value_for_money'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 75, u'type': u'service'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 75, u'type': u'cleanliness'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 74, u'type': u'comfort'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 72, u'type': u'facilities'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 73, u'type': u'location'}]
# Processing Hotel id 1503119
# 	311
# 	[{u'advertiserLink': u'c9ZXS&X:.Y7Yba01/=AKpSzKFkpOx3BKN%lKxNeLKMjNxnJut84NxJxywSFVtu8:VIQ:NNRNN3SQQQ7KrSJLVMoMxnJHHn4AxeAQItEGwMBDrNnIxn4QxnNpQxntV43Gr8tLNIBNL4tAGNp:tnAwpJE::RVHAMjtNtfELNApVMtCL4WuN4YEL4FVx5QMuNFJutZ1r4QxG8UHNQxuJRY9VRJ/A2WoItQCw8APKNUBJuQosJZBssg/JJxCGSV%mMV3WGMJoLsSe0ItSCwtIxJR:tJt:VJ4J/9VJ&IxRLJQxULNRQrMIyCGMQJ2eHNVoIIxtBpM4IxIZDQ8%lK%lK', u'ratingPercentage': 67, u'id': 57, u'name': u'Holidaycheck'}, {u'advertiserLink': u'', u'ratingPercentage': 78, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 3, u'percentage': 78}
# 	False
# 	[{u'ratingText': u'Aceptable', u'index': 2, u'percentage': 73, u'type': u'value_for_money'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 74, u'type': u'room'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 79, u'type': u'service'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 77, u'type': u'cleanliness'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 73, u'type': u'comfort'}, {u'ratingText': u'\u0e22\u0e01Buena!', u'index': 3, u'percentage': 75, u'type': u'food_and_drinks'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage':
rNRVHxNRLM87IQ3RnMJoHr7x?sNxVsVRuNMIBJKEtMIV/QntLHSRtMt:xM87tKtoKrxMQJ2eHNVoIIxtB?R4LQNWDKGt1VMYvISfHJ8jsVu/:KtoCMIF%lK', u'ratingPercentage': 78, u'id': 406, u'name': u'Expedia'}, {u'advertiserLink': u'', u'ratingPercentage': 81, u'id': 0, u'name': u'Otras fuentes'}]
# 	{u'index': 4, u'percentage': 80}
# 	False
# 	[{u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 81, u'type': u'value_for_money'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 79, u'type': u'room'}, {u'ratingText': u'Aceptable', u'index': 2, u'percentage': 72, u'type': u'service'}, {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 84, u'type': u'cleanliness'}, {u'ratingText': u'\xa1Excelente!', u'index': 5, u'percentage': 88, u'type': u'comfort'}, {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 80, u'type': u'facilities'}, {u'ratingText': u'\xa1Buena!', u'index': 3, u'percentage': 75, u'type': u'location'}, {u'ratingText': u'\xa1Muy buena!', u'index': 4, u'percentage': 83, u'type': u'hotel_condition'}]
# Processing Hotel id 2726412
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-d7ec6e8453ac> in <module>()
#       6     params = dict(requestId="v11_03_1_ae_es_ES_ES")
#       7
# ----> 8     data = requests.get(url=url, params=params)
#       9     data_json = json.loads(data.text)
#      10
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382         try:
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#     386                 try:
#
# /Users/pere/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /Users/pere/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /Users/pere/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /Users/pere/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/pere/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     231     def recv(self, *args, **kwargs):
#     232         try:
# --> 233             data = self.connection.recv(*args, **kwargs)
#     234         except OpenSSL.SSL.SysCallError as e:
#     235             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/pere/anaconda/lib/python2.7/site-packages/OpenSSL/SSL.pyc in recv(self, bufsiz, flags)
#    1301             result = _lib.SSL_peek(self._ssl, buf, bufsiz)
#    1302         else:
# -> 1303             result = _lib.SSL_read(self._ssl, buf, bufsiz)
#    1304         self._raise_ssl_error(self._ssl, result)
#    1305         return _ffi.buffer(buf, result)[:]
#
# KeyboardInterrupt:
